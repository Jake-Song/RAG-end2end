# %%
from typing import TypedDict, Annotated, List
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
class Metadata(TypedDict):
    id: int
    page: int
    category: str
    html: str
    base64_encoding: str
    image_id: List[int]
    image_path: List[str]

# %%
class Element(TypedDict):
    page_content: Annotated[str, "page_content"]
    metadata: Annotated[Metadata, "metadata"]

# %%
# State 정의
class State(TypedDict):
    config: Annotated[Config, "config"]
    elements: Annotated[List[Element], "elements"]

# %%
class Config(TypedDict):
    batch_size: Annotated[int, "batch_size"]
    input_file: Annotated[str, "input_file"]
    json_file: Annotated[str, "json_file"]
    output_prefix: Annotated[str, "output_prefix"]

# %%
# Configuration
input_file = "data/sample.pdf"  # Replace with a file of your own
batch_size = 10  # Maximum available value is 100

# Input parameters
json_file = "data/sample_0_9.json"
output_prefix = "images/sample_0_9_cropped"

# %%
config = Config(input_file=input_file, batch_size=batch_size, json_file=json_file, output_prefix=output_prefix)

# %%
# Parse
def split_pdf(state: State) -> State:
    return state

def output_json(state: State) -> State:
   
    return state

def process_data(state: State) -> State:
    return state

def extrct_image(state: State) -> State:
    return state

def merge_by_page(state: State) -> State:
    return state

def save_object(state: State) -> State:
    return state

# %%
# Chunk
def load_object(state: State) -> State:
    return state

def summarize_image(state: State) -> State:
    return state

def summarize_text(state: State) -> State:
    return state

def split_document(state: State) -> State:
    return state

def save_split_document(state: State) -> State:
    return state

# %%
# Retrieve
def load_split_document(state: State) -> State:
    return state

def embedding(state: State) -> State:
    return state

def retrieve(state: State) -> State:
    return state

def save_embedding(state: State) -> State:
    return state
