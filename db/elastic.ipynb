# %%
import sys
from pathlib import Path
root = Path().resolve().parent  # adjust level as needed
sys.path.insert(0, str(root))

# %%
import pickle
papers = []
for path in sorted(Path(root).joinpath("outputs").glob("SPRI_*_split_documents.pkl")):
    
    with open(path, "rb") as f:
        split_documents = pickle.load(f)
        for doc in split_documents:
            name = path.stem.replace("_output_split_documents", "")
            doc.metadata["title"] = name
           
            if name in ["SPRI_2022", "SPRI_2023", "SPRI_2025"]:
                doc.metadata["category"] = "AI-index"
                if name == "SPRI_2022":
                    doc.metadata["tag"] = ["AI인덱스", "AI트렌드", "AI윤리", "AI인재"]
                elif name == "SPRI_2023":
                    doc.metadata["tag"] = ["AI인덱스", "AI트렌드", "AI규제", "AI인재"]
                elif name == "SPRI_2025":
                    doc.metadata["tag"] = ["AI인덱스", "AI트렌드", "AI스타트업", "정부정책"]
            elif "SPRI_is" in name:
                doc.metadata["category"] = "issue-report"
                if name == "SPRI_is_211":
                    doc.metadata["tag"] = ["AI스타트업", "기술사업화", "기업가정신", "AI인재"]
                elif name == "SPRI_is_212":
                    doc.metadata["tag"] = ["SW안전", "기능안전", "오토파일럿"]
                elif name == "SPRI_is_213":
                    doc.metadata["tag"] = ["미래기술", "산업전망", "AI스타트업", "AI인재"]
            elif "SPRI_c" in name:
                doc.metadata["category"] = "column"
                if name == "SPRI_c_1":
                    doc.metadata["tag"] = ["Govtech", "정부혁신", "디지털정부", "제도주의"]
                elif name == "SPRI_c_2":
                    doc.metadata["tag"] = ["개방형혁신", "SaaS", "AI인재"]
                elif name == "SPRI_c_3":
                    doc.metadata["tag"] = ["산업전망", "기업가정신", "AI윤리", "AI인재"]
                
                    
    papers.extend(split_documents)

# %%
import os
from elasticsearch import Elasticsearch
from langchain_upstage import UpstageEmbeddings
from dotenv import load_dotenv
load_dotenv(root.joinpath("elastic-start-local/.env"))
URL = os.environ["ES_LOCAL_URL"]
API_KEY = os.environ["ES_LOCAL_API_KEY"]
es = Elasticsearch(
    URL,
    api_key=API_KEY
)

# %%
# Load a sentence transformer model for generating embeddings
model = UpstageEmbeddings(model="embedding-passage")  
# Index name
index_name = "vector_search_demo"

# Create index with vector field mapping
mapping = {
    "mappings": {
        "properties": {
            "text": {"type": "text"},
            "metadata": {
                "properties": {
                    "page": {"type": "integer"},
                    "image_id": {"type": "integer"},
                    "image_path": {"type": "keyword"},
                    "text_summary": {"type": "text"},
                    "image_summary": {"type": "text"},
                    "id": {"type": "keyword"},
                    "title": {"type": "keyword"},
                    "category": {"type": "keyword"},
                    "tag": {"type": "keyword"}                   
                }
            },
            "vector": {
                "type": "dense_vector",
                "dims": 4096,  # Dimension of all-MiniLM-L6-v2 embeddings
                "index": True,
                "similarity": "cosine"
            }
        }
    }
}

# Delete index if exists and create new one
if es.indices.exists(index=index_name):
    es.indices.delete(index=index_name)
es.indices.create(index=index_name, body=mapping)
print(f"Created index: {index_name}")
# Out:
# Created index: vector_search_demo

# %%
import uuid
# Index documents with their embeddings
print("\nIndexing documents...")
for i, doc in enumerate(papers, 1):
    print(doc.metadata)
        
    # Generate embedding
    embedding = model.embed_query(doc.page_content)
    
    # Index document
    doc = {
        "text": doc.page_content,
        "metadata": doc.metadata,
        "vector": embedding
    }
    es.index(index=index_name, id=uuid.uuid4(), document=doc)
    print(f"Indexed: doc_id:{i}")
# Out:
# Indexing documents...
# {'page': 1, 'image_id': [], 'image_path': [], 'text_summary': [], 'image_summary': [], 'id': 0, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:1
# {'page': 2, 'image_id': [], 'image_path': [], 'text_summary': [], 'image_summary': [], 'id': 1, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:2
# {'page': 3, 'image_id': [], 'image_path': [], 'text_summary': [], 'image_summary': [], 'id': 2, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:3
# {'page': 4, 'image_id': [], 'image_path': [], 'text_summary': [], 'image_summary': [], 'id': 3, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:4
# {'page': 5, 'image_id': [], 'image_path': [], 'text_summary': '다음은 주어진 텍스트의 한국어 요약입니다.\n\n- Stanford의 Human-centered Artificial Intelligence Institute(HAI)가 AI Index 2022를 발표. 보고서는 다섯 챕터(R&D, 기술 성능, 기술 윤리, 경제·교육, AI 정책 거버넌스)로 구성되며, 올해는 챕터 2에 기술 성능 분석, 챕터 3에 AI 윤리 심층 분석이 새로 포함됨.\n\n- 2021년 AI 분야 민간 투자액은 935억 달러로 2020년 대비 두 배 증가. 미국과 중국이 R&D와 스타트업 생태계를 주도하나, 기술 주도 경쟁 속에서도 연구 분야에서의 협력이 증가.\n\n- 대형 언어모델(LLM) 성능은 데이터 및 파라미터 처리의 개선으로 향상되었으나 편향 문제도 함께 증가하는 양상. AI 윤리 및 신뢰성 이슈가 부각되며, 이와 관련한 활발한 연구 진행.\n\n- 기술 성능은 개선되는 한편 비용은 크게 감소하고 연구 진입 장벽은 낮아지는 경향.\n\n- 전 세계적으로 AI 관련 입법 활동이 활발하지만 여전히 미완성 상태.\n\n- 한국은 publications와 patents 등에서 연구개발 측면의 상당한 진전을 보였으나, 신뢰할 수 있는(trustworthy) AI 기술 개발, 고용, 교육, 입법 분야에 대한 지속적 투자가 필요.', 'image_summary': [], 'id': 4, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:5
# {'page': 5, 'image_id': [], 'image_path': [], 'text_summary': '다음은 주어진 텍스트의 한국어 요약입니다.\n\n- Stanford의 Human-centered Artificial Intelligence Institute(HAI)가 AI Index 2022를 발표. 보고서는 다섯 챕터(R&D, 기술 성능, 기술 윤리, 경제·교육, AI 정책 거버넌스)로 구성되며, 올해는 챕터 2에 기술 성능 분석, 챕터 3에 AI 윤리 심층 분석이 새로 포함됨.\n\n- 2021년 AI 분야 민간 투자액은 935억 달러로 2020년 대비 두 배 증가. 미국과 중국이 R&D와 스타트업 생태계를 주도하나, 기술 주도 경쟁 속에서도 연구 분야에서의 협력이 증가.\n\n- 대형 언어모델(LLM) 성능은 데이터 및 파라미터 처리의 개선으로 향상되었으나 편향 문제도 함께 증가하는 양상. AI 윤리 및 신뢰성 이슈가 부각되며, 이와 관련한 활발한 연구 진행.\n\n- 기술 성능은 개선되는 한편 비용은 크게 감소하고 연구 진입 장벽은 낮아지는 경향.\n\n- 전 세계적으로 AI 관련 입법 활동이 활발하지만 여전히 미완성 상태.\n\n- 한국은 publications와 patents 등에서 연구개발 측면의 상당한 진전을 보였으나, 신뢰할 수 있는(trustworthy) AI 기술 개발, 고용, 교육, 입법 분야에 대한 지속적 투자가 필요.', 'image_summary': [], 'id': 5, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:6
# {'page': 5, 'image_id': [], 'image_path': [], 'text_summary': '다음은 주어진 텍스트의 한국어 요약입니다.\n\n- Stanford의 Human-centered Artificial Intelligence Institute(HAI)가 AI Index 2022를 발표. 보고서는 다섯 챕터(R&D, 기술 성능, 기술 윤리, 경제·교육, AI 정책 거버넌스)로 구성되며, 올해는 챕터 2에 기술 성능 분석, 챕터 3에 AI 윤리 심층 분석이 새로 포함됨.\n\n- 2021년 AI 분야 민간 투자액은 935억 달러로 2020년 대비 두 배 증가. 미국과 중국이 R&D와 스타트업 생태계를 주도하나, 기술 주도 경쟁 속에서도 연구 분야에서의 협력이 증가.\n\n- 대형 언어모델(LLM) 성능은 데이터 및 파라미터 처리의 개선으로 향상되었으나 편향 문제도 함께 증가하는 양상. AI 윤리 및 신뢰성 이슈가 부각되며, 이와 관련한 활발한 연구 진행.\n\n- 기술 성능은 개선되는 한편 비용은 크게 감소하고 연구 진입 장벽은 낮아지는 경향.\n\n- 전 세계적으로 AI 관련 입법 활동이 활발하지만 여전히 미완성 상태.\n\n- 한국은 publications와 patents 등에서 연구개발 측면의 상당한 진전을 보였으나, 신뢰할 수 있는(trustworthy) AI 기술 개발, 고용, 교육, 입법 분야에 대한 지속적 투자가 필요.', 'image_summary': [], 'id': 6, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:7
# {'page': 6, 'image_id': [], 'image_path': [], 'text_summary': [], 'image_summary': [], 'id': 7, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:8
# {'page': 7, 'image_id': [45], 'image_path': ['/images/SPRI_2022_cropped_chart_45.png'], 'text_summary': '다음은 제시된 한국어 텍스트의 요약입니다.\n\n- 주제 및 목적\n  - SPRi 이슈리포트 IS-139는 AI Index 2022의 주요 내용과 시사점을 정리합니다.\n  - 특히 연구개발(R&D) 동향을 출판물과 특허 데이터를 통해 분석하는 방식으로 AI 성과를 살핍니다.\n\n- 2.1 연구개발(R&D) 동향 분석\n  - 연구개발 성과는 AI 발전의 핵심 동력으로 간주되며, 성과는 다양한 형태의 출판물과 특허 데이터를 이용해 분석합니다.\n\n- 1. 연구개발 성과\n  - 2021년에도 AI 연구개발 성과의 출판이 지속적으로 성장했습니다.\n  - 전 세계 AI 관련 출판물의 증가 추세가 확인되며, 특히 패턴 인식(pattern recognition)과 머신러닝(machine learning) 분야의 성장이 두드러집니다.\n\n- 그림 및 수치\n  - 그림: 2010–2021년 전 세계 인공지능 관련 출판물 증가 추이(연도별 증가).\n  - 표기 및 차트 형식: 저널 논문과 온라인 사전출판(arXiv) 등 출판물 형태(type)와 세부 분야(sector)로 분류된 추세를 제시.\n  - 2021년 저널 논문의 비중은 약 2.5%로 제시되며(2010년 약 1.5%에 비해 증가), 전체 컨퍼런스 논문 등과의 비교를 포함한 맥락으로 설명됩니다. (주석의 문맥상 수치 해석은 보완 필요 시 확인 권장)\n\n- 출판물의 유형 및 세부 분야\n  - 출판물 유형(type): 7가지로 분류\n    - book, book chapter, 컨퍼런스 논문, 저널 논문, 학위논문, 온라인 사전출판(arXiv), 기타(unknown)\n  - 세부 분야(sector): 10가지로 분류\n    - 패턴인식, 알고리즘, 컴퓨터 비전, 자연어처리, 휴먼-AI 상호작용, 데이터 마이닝, 컨트롤 이론, 기계학습, 언어학, 기타 AI\n  - 이 분류는 미국 조지타운대학의 CSET가 수행한 것으로, AI 출판물의 유형과 세부 분야를 체계적으로 분석하기 위한 것입니다.\n\n- 용어 정의 및 배경\n  - arXiv, SSRN 등과 같은 논문 저장소에 공유되는 온라인 사전출판은 작성 직후 공개되어 AI 연구성과의 빠른 확산에 기여하는 일반적 관행으로 소개됩니다.\n  - 요약적으로, AI 연구 성과의 확산과 분석에 있어 출판물 형태와 분야의 분류 체계가 중요하게 다뤄집니다.\n\n요약하면, 이 문서는 AI Index 2022의 핵심 메시지로서 AI 연구의 성과를 출판물과 특허를 통해 측정하고, 2021년에도 출판 생산이 계속 증가했으며, 특히 패턴 인식과 머신러닝 분야의 성장이 두드러진다고 정리합니다. 또한 출판물의 유형과 세부 분야를 체계적으로 분류하는 기준을 제시하고, arXiv 같은 선행출판의 역할을 강조하고 있습니다.', 'image_summary': '다음과 같은 내용을 담은 바 차트입니다.\n\n- 제목/주제: 2010년부터 2021년까지 전 세계 인공지능 관련 출판물 증가 추이(그림 2-1-1).\n- 축 구성: 가로축은 연도(2010–2021), 세로축은 인공지능 관련 출판물 수를 천 단위로 표시(단위: thousands).\n- 시각적 내용: 파란색 바가 매년 점진적으로 상승하는 모습을 보이며, 연도 증가에 따라 출판물 수가 늘어나는 상승 추세를 나타냅니다.\n- 수치 예시: 2010년경 약 160,000편에서 시작해 2021년 약 334,500편으로 증가합니다. 2018년 이후 급격한 증가가 나타나고, 2019년~2020년대 초에 더 큰 상승이 이어집니다.\n- 바의 끝에는 2021년 수치로 334.50이 표시되어 있습니다.\n\n요약하자면, 이 차트는 2010년대 초반부터 2021년까지 AI 관련 출판물이 꾸준히 증가해 왔음을 보여주는 바 차트입니다.', 'id': 8, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:9
# {'page': 7, 'image_id': [45], 'image_path': ['/images/SPRI_2022_cropped_chart_45.png'], 'text_summary': '다음은 제시된 한국어 텍스트의 요약입니다.\n\n- 주제 및 목적\n  - SPRi 이슈리포트 IS-139는 AI Index 2022의 주요 내용과 시사점을 정리합니다.\n  - 특히 연구개발(R&D) 동향을 출판물과 특허 데이터를 통해 분석하는 방식으로 AI 성과를 살핍니다.\n\n- 2.1 연구개발(R&D) 동향 분석\n  - 연구개발 성과는 AI 발전의 핵심 동력으로 간주되며, 성과는 다양한 형태의 출판물과 특허 데이터를 이용해 분석합니다.\n\n- 1. 연구개발 성과\n  - 2021년에도 AI 연구개발 성과의 출판이 지속적으로 성장했습니다.\n  - 전 세계 AI 관련 출판물의 증가 추세가 확인되며, 특히 패턴 인식(pattern recognition)과 머신러닝(machine learning) 분야의 성장이 두드러집니다.\n\n- 그림 및 수치\n  - 그림: 2010–2021년 전 세계 인공지능 관련 출판물 증가 추이(연도별 증가).\n  - 표기 및 차트 형식: 저널 논문과 온라인 사전출판(arXiv) 등 출판물 형태(type)와 세부 분야(sector)로 분류된 추세를 제시.\n  - 2021년 저널 논문의 비중은 약 2.5%로 제시되며(2010년 약 1.5%에 비해 증가), 전체 컨퍼런스 논문 등과의 비교를 포함한 맥락으로 설명됩니다. (주석의 문맥상 수치 해석은 보완 필요 시 확인 권장)\n\n- 출판물의 유형 및 세부 분야\n  - 출판물 유형(type): 7가지로 분류\n    - book, book chapter, 컨퍼런스 논문, 저널 논문, 학위논문, 온라인 사전출판(arXiv), 기타(unknown)\n  - 세부 분야(sector): 10가지로 분류\n    - 패턴인식, 알고리즘, 컴퓨터 비전, 자연어처리, 휴먼-AI 상호작용, 데이터 마이닝, 컨트롤 이론, 기계학습, 언어학, 기타 AI\n  - 이 분류는 미국 조지타운대학의 CSET가 수행한 것으로, AI 출판물의 유형과 세부 분야를 체계적으로 분석하기 위한 것입니다.\n\n- 용어 정의 및 배경\n  - arXiv, SSRN 등과 같은 논문 저장소에 공유되는 온라인 사전출판은 작성 직후 공개되어 AI 연구성과의 빠른 확산에 기여하는 일반적 관행으로 소개됩니다.\n  - 요약적으로, AI 연구 성과의 확산과 분석에 있어 출판물 형태와 분야의 분류 체계가 중요하게 다뤄집니다.\n\n요약하면, 이 문서는 AI Index 2022의 핵심 메시지로서 AI 연구의 성과를 출판물과 특허를 통해 측정하고, 2021년에도 출판 생산이 계속 증가했으며, 특히 패턴 인식과 머신러닝 분야의 성장이 두드러진다고 정리합니다. 또한 출판물의 유형과 세부 분야를 체계적으로 분류하는 기준을 제시하고, arXiv 같은 선행출판의 역할을 강조하고 있습니다.', 'image_summary': '다음과 같은 내용을 담은 바 차트입니다.\n\n- 제목/주제: 2010년부터 2021년까지 전 세계 인공지능 관련 출판물 증가 추이(그림 2-1-1).\n- 축 구성: 가로축은 연도(2010–2021), 세로축은 인공지능 관련 출판물 수를 천 단위로 표시(단위: thousands).\n- 시각적 내용: 파란색 바가 매년 점진적으로 상승하는 모습을 보이며, 연도 증가에 따라 출판물 수가 늘어나는 상승 추세를 나타냅니다.\n- 수치 예시: 2010년경 약 160,000편에서 시작해 2021년 약 334,500편으로 증가합니다. 2018년 이후 급격한 증가가 나타나고, 2019년~2020년대 초에 더 큰 상승이 이어집니다.\n- 바의 끝에는 2021년 수치로 334.50이 표시되어 있습니다.\n\n요약하자면, 이 차트는 2010년대 초반부터 2021년까지 AI 관련 출판물이 꾸준히 증가해 왔음을 보여주는 바 차트입니다.', 'id': 9, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:10
# {'page': 8, 'image_id': [58], 'image_path': ['/images/SPRI_2022_cropped_chart_58.png'], 'text_summary': '요약\n\n- AI Index 2022의 핵심 시사점은 AI 관련 콘텐츠의 높은 점유율과 빠른 성장세, 그리고 AI 특허의 급격한 증가를 보여줌.\n- AI 특허 출원은 2021년에 2015년 대비 30배 이상 증가했고 연평균 성장률은 76.9%를 기록, 중국의 급격한 증가가 큰 요인으로 작용.\n- 글로벌 AI 특허 출원과 등록의 다수는 미국, 중국, 유럽·영국이 차지하며, 각각 세계의 절반 이상(출원 72.5%, 등록 53.1%)을 구성.\n- 연구개발 주체 측면에서 대학은 핵심 주체로 구심점 역할을 하며, AI 출판물의 약 60%를 담당. 비영리기관 11.3%, 기업 5.2%, 정부 3.2% 등은 상대적으로 낮은 비중.\n- 협력관계에서도 대학이 상위 3개의 협력유형에 모두 포함될 만큼 연구협력의 중심역할을 수행.', 'image_summary': '다음은 이미지의 내용 요약입니다.\n\n- 그림 제목/그림 번호: 그림 2-1-2 인공지능 특허 출원 추이(2010-2021)\n- 차트 유형: 막대그래프(bar)\n- 축 설명:\n  - x축: 연도(2010, 2011, ..., 2021)\n  - y축: 인공지능 특허 출원 건수(천 단위)\n- 데이터 출처: Stanford HAI, AI Index Report 2022\n- 관찰 내용:\n  - 2010년대 초반은 출원 건수가 매우 작음\n  - 2017년 이후 출원 건수가 급격히 증가하기 시작\n  - 2018년 약 20천 건, 2019년 약 40천 건, 2020년 약 80천 건\n  - 2021년 약 141.24천 건으로 최고치 도달\n- 전체 요지: AI 특허 출원 건수가 해마다 크게 증가하고 있으며, 2017년 이후 증가 속도가 가파르게 올라갔음을 시각적으로 보여주는 그래프입니다.', 'id': 10, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:11
# {'page': 8, 'image_id': [58], 'image_path': ['/images/SPRI_2022_cropped_chart_58.png'], 'text_summary': '요약\n\n- AI Index 2022의 핵심 시사점은 AI 관련 콘텐츠의 높은 점유율과 빠른 성장세, 그리고 AI 특허의 급격한 증가를 보여줌.\n- AI 특허 출원은 2021년에 2015년 대비 30배 이상 증가했고 연평균 성장률은 76.9%를 기록, 중국의 급격한 증가가 큰 요인으로 작용.\n- 글로벌 AI 특허 출원과 등록의 다수는 미국, 중국, 유럽·영국이 차지하며, 각각 세계의 절반 이상(출원 72.5%, 등록 53.1%)을 구성.\n- 연구개발 주체 측면에서 대학은 핵심 주체로 구심점 역할을 하며, AI 출판물의 약 60%를 담당. 비영리기관 11.3%, 기업 5.2%, 정부 3.2% 등은 상대적으로 낮은 비중.\n- 협력관계에서도 대학이 상위 3개의 협력유형에 모두 포함될 만큼 연구협력의 중심역할을 수행.', 'image_summary': '다음은 이미지의 내용 요약입니다.\n\n- 그림 제목/그림 번호: 그림 2-1-2 인공지능 특허 출원 추이(2010-2021)\n- 차트 유형: 막대그래프(bar)\n- 축 설명:\n  - x축: 연도(2010, 2011, ..., 2021)\n  - y축: 인공지능 특허 출원 건수(천 단위)\n- 데이터 출처: Stanford HAI, AI Index Report 2022\n- 관찰 내용:\n  - 2010년대 초반은 출원 건수가 매우 작음\n  - 2017년 이후 출원 건수가 급격히 증가하기 시작\n  - 2018년 약 20천 건, 2019년 약 40천 건, 2020년 약 80천 건\n  - 2021년 약 141.24천 건으로 최고치 도달\n- 전체 요지: AI 특허 출원 건수가 해마다 크게 증가하고 있으며, 2017년 이후 증가 속도가 가파르게 올라갔음을 시각적으로 보여주는 그래프입니다.', 'id': 11, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:12
# {'page': 9, 'image_id': [71], 'image_path': ['/images/SPRI_2022_cropped_chart_71.png'], 'text_summary': '다음은 제시된 텍스트의 한국어 요약입니다.\n\n- 주제: SPRi 이슈리포트 IS-139는 AI Index 2022의 주요 내용 및 시사점을 정리합니다.\n- 기관 간 AI 출판물 협력 비중: 대학-비영리기관 29.84%, 기업-대학 11.58%, 대학-정부 8.09%가 상위 순위를 이룹니다.\n- 미‧중 간 AI 양상: 중국은 양적 연구에서 이미 미국을 앞서고, 질적 부문에서도 일부 앞서가며 미국과 함께 2강 체제를 확립하는 구도로 설명됩니다.\n- 2021년 기준 총 논문(저널+컨퍼런스+온라인 사전출판)을 합산하면 중국이 미국보다 63.2% 많은 논문을 발표한 것으로 나타납니다.\n- 사전출판 논문: 수와 인용에서 미국에 아직 뒤지나, 지난 12년간 격차를 꾸준히 좁히고 있습니다.\n- 컨퍼런스 논문 인용: 2019년까지는 상승하다가 이후 점유율이 떨어지는 경향이며, 미국과 유럽이 여전히 상위권 3국으로 이어지고 있습니다.\n- 그림(그림 2-1-3): 2010-2021년 지역별 인공지능 논문 인용 비중 추이를 보여주는 시각 자료가 제시됩니다.', 'image_summary': '다음은 이미지의 내용 요약입니다.\n\n- 주제: 2010년부터 2021년까지 지역별 인공지능 논문 인용 비중의 추이(그림 2-1-3).\n- 축: 가로축은 연도(2010–2021), 세로축은 세계 총 인용 대비 각 지역의 비율(%).\n- 지역 구분 및 색상: 중국(보라색 선), 유럽&영국(푸른 선), 미국(청록색 선).\n- 2021년 수치:\n  - 중국: 27.84% (가장 높음)\n  - 유럽&영국: 21.13%\n  - 미국: 17.45%\n- 트렌드 요지:\n  - 중국의 인용 비중이 지속적으로 증가해 2021년에는 선두를 차지함.\n  - 미국의 비중은 비교적 초기에는 비슷하거나 높았으나 점차 감소하는 경향.\n  - 유럽&영국의 비중은 비교적 안정적이거나 다소 변동했으며, 2021년에는 중국에 이어 두 번째로 높은 편에 위치.', 'id': 12, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:13
# {'page': 10, 'image_id': [85], 'image_path': ['/images/SPRI_2022_cropped_chart_85.png'], 'text_summary': [], 'image_summary': '다음은 이미지의 내용 요약입니다.\n\n- 그림 유형: 선 그래프[그림 2-1-4]으로, 2010년부터 2021년까지 미국과 중국의 AI 출판물 협력 추이를 보여줌.\n- 축 구성: x축은 연도(2010–2021), y축은 공동 저술된 AI 출판물 수(단위: 천 편).\n- 데이터 흐름: 협력 규모가 해마다 증가하는 추세를 보임.\n  - 2010년 약 2.5천 편에서 시작\n  - 2012년 약 3천 편, 2014년 약 4천 편으로 증가\n  - 2016년 약 5천 편, 2018년 약 6천 편으로 상승\n  - 2019년 약 7천 편, 2020년 약 8천 편으로 지속 증가\n  - 2021년 약 9.66천 편으로 최고치 도달\n- 해석: 미국과 중국 간 AI 연구 협력이 시간이 지날수록 강화되고 있음을 시사.\n- 출처: Stanford HAI, AI Index Report 2022.', 'id': 13, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:14
# {'page': 11, 'image_id': [], 'image_path': [], 'text_summary': '요약\n- IS-139의 2.2항은 AI 기술 부문 중 특히 컴퓨터 비전에 대해 벤치마크와 정량 평가를 통해 성능 발전 양상을 분석한다. 이미지 분류와 이미지 생성의 최근 성과를 중심으로 다룬다.\n\n주요 내용\n- 컴퓨터 비전의 두 축\n  - 이미지 분류(Image Classification): 최근 10년간 급격한 성능 향상. 예시로 구글 Brain Team의 CoAtNets가 2021년 말 Top-1 에러율이 1/10 수준(인식률 90.88%)에 도달했고, 2012년 대비 1/4 수준으로 감소. MS의 Florence-CoSwim-H는 2021년 기준 Top-5 정확도 99.02%에 달해 2012년 약 84% 대비 15%p 이상 향상.\n  - 이미지 생성(Image Generation): 실제와 구별 가능한 이미지 생성을 목표로 하며, 지난 3~4년 사이 성능이 크게 향상. 다양한 분야에서의 활용 가능성이 제시된다.\n- 벤치마크 데이터\n  - 2009년 제작된 데이터베이스로, 2만 가지 분야의 총 1,400만 개 이상 이미지를 포함하며 AI 이미지 분류의 대표 벤치마크로 활용된다.', 'image_summary': [], 'id': 14, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:15
# {'page': 11, 'image_id': [], 'image_path': [], 'text_summary': '요약\n- IS-139의 2.2항은 AI 기술 부문 중 특히 컴퓨터 비전에 대해 벤치마크와 정량 평가를 통해 성능 발전 양상을 분석한다. 이미지 분류와 이미지 생성의 최근 성과를 중심으로 다룬다.\n\n주요 내용\n- 컴퓨터 비전의 두 축\n  - 이미지 분류(Image Classification): 최근 10년간 급격한 성능 향상. 예시로 구글 Brain Team의 CoAtNets가 2021년 말 Top-1 에러율이 1/10 수준(인식률 90.88%)에 도달했고, 2012년 대비 1/4 수준으로 감소. MS의 Florence-CoSwim-H는 2021년 기준 Top-5 정확도 99.02%에 달해 2012년 약 84% 대비 15%p 이상 향상.\n  - 이미지 생성(Image Generation): 실제와 구별 가능한 이미지 생성을 목표로 하며, 지난 3~4년 사이 성능이 크게 향상. 다양한 분야에서의 활용 가능성이 제시된다.\n- 벤치마크 데이터\n  - 2009년 제작된 데이터베이스로, 2만 가지 분야의 총 1,400만 개 이상 이미지를 포함하며 AI 이미지 분류의 대표 벤치마크로 활용된다.', 'image_summary': [], 'id': 15, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:16
# {'page': 12, 'image_id': [110, 116, 118], 'image_path': ['/images/SPRI_2022_cropped_table_110.png', '/images/SPRI_2022_cropped_chart_116.png', '/images/SPRI_2022_cropped_chart_118.png'], 'text_summary': '이 글은 이미지 분류와 이미지 생성 AI의 성능 평가 방법 및 최근 벤치마크의 시사점을 정리합니다.\n\n주요 내용 요약\n- 이미지 분류 성능 평가 지표\n  - 보통 Top-1 Accuracy와 Top-5 Accuracy를 사용합니다.\n  - 예시: 클래스 10개 중 가장 높은 확률의 Top-1 클래스와 상위 5개 확률의 Top-5 클래스를 판단 기준으로 삼습니다.\n  - Top-1 학습 예측이 가장 잘 맞는 이미지의 확률을 Top-1 Accuracy로, 상위 5개 예측이 잘 맞는 이미지의 확률을 Top-5 Accuracy로 측정합니다.\n  - 일반적으로 에러율 5% 이하(인식률 95% 이상)를 달성하면 분류 능력이 높다고 봅니다. 사람의 인식률과 비교하면 대략 94.9% 수준으로 언급됩니다.\n- 이미지 생성 AI의 벤치마크\n  - 벤치마크로는 STL-10과 CIFAR-10 데이터셋의 프리셰 인셉션 거리(FID)를 사용합니다. FID 점수가 낮을수록 실제와 비슷하다는 뜻으로 성능이 좋다는 판단을 내립니다.\n  - STL-10 기반 KAIST와 서울대의 최신 모델은 FID 약 7.7로, 2018–2020년 모델의 약 25–35 수준에 비해 크게 개선되었습니다.\n  - CIFAR-10 기반 엔비디아 모델은 FID 약 2.2로 과거 대비 큰 향상을 보였습니다.\n  - 주의: CIFAR-10은 STL-10보다 해상도가 낮아 FID 점수가 상대적으로 낮게 나올 수 있고, 두 모델의 절대 성능 비교는 직접적이지 않습니다.\n- 부가 정보\n  - 수치의 출처는 Stanford HAI의 AI Index Report 2022(재편집)이며, 그림 2-2-1은 이미지 생성 AI의 성능 변화를 시각적으로 보여줍니다.\n  - FID의 정의와 해석에 대한 주석(6번, 7번 참조)이 포함되어 있습니다.', 'image_summary': ['이 이미지는 두 줄로 구성된 표이다.\n\n- 열 헤더: Class, Rate\n- 클래스 목록: 비행기, 자동차, 새, 고양이, 사슴, 개, 개구리, 말, 배, 트럭\n- 각 클래스에 대응하는 확률(Rate) 값: 비행기 0.5, 자동차 0.1, 새 0.03, 고양이 0.02, 사슴 0, 개 0.1, 개구리 0, 말 0.2, 배 0.05, 트럭 0\n\n즉, 예시 분류기의 Top-1/Top-5 예측에서 각 클래스에 할당된 확률을 나타낸 표이다.', '이 이미지는 2018년부터 2021년까지 이미지 생성 AI의 성능 변화를 나타내는 FID(Frechet Inception Distance) 점수의 추세선을 보여주는 그래프입니다. \n- y축: FID 점수(값이 낮을수록 성능이 좋음)\n- x축: 연도(2018, 2019, 2020, 2021)\n- 그래프는 해가 지날수록 점수가 점차 낮아지는 하락 추세를 보여주며, 2021년 끝점은 7.71로 표기되어 있습니다.\n- FID는 생성 이미지와 실제 이미지 간의 분포 차이를 측정하는 지표로, 값이 작아질수록 생성 품질이 좋아지는 것을 의미합니다.', '다음은 그림(그림 2-2-1)의 내용 설명입니다.\n\n- 그림 제목/용도: 그림 2-2-1 이미지 생성 AI의 성능 변화. 이미지 생성 AI의 품질을 나타내는 FID(Frechet Inception Distance) 점수의 연도별 변화를 보여주는 선 그래프입니다.\n- 축 및 구성: 가로축은 연도(2017~2021), 세로축은 FID 점수(0~약 30). 점수가 낮을수록 생성된 이미지가 실제 이미지와 더 비슷하다는 것을 의미합니다.\n- 데이터 경향: 2017년 약 30에서 시작해 2018년 약 15로 급격히 감소하고, 2019년 부근에 약 12~13으로 이어진 뒤 2020년대에 3~4로 크게 낮아지며, 2021년에는 약 2.1로 더 떨어지는 경향을 보입니다.\n- 해석 포인트: FID 점수는 낮을수록 실제 이미지와의 차이가 작아지며 구별하기 어려워진다는 의미입니다. FID 0은 완전히 동일한 이미지를 뜻합니다.\n- 요약: 이 그림은 2017년から2021년까지 이미지 생성 AI의 품질이 지속적으로 향상되었음을 시각적으로 보여줍니다.'], 'id': 16, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:17
# {'page': 12, 'image_id': [110, 116, 118], 'image_path': ['/images/SPRI_2022_cropped_table_110.png', '/images/SPRI_2022_cropped_chart_116.png', '/images/SPRI_2022_cropped_chart_118.png'], 'text_summary': '이 글은 이미지 분류와 이미지 생성 AI의 성능 평가 방법 및 최근 벤치마크의 시사점을 정리합니다.\n\n주요 내용 요약\n- 이미지 분류 성능 평가 지표\n  - 보통 Top-1 Accuracy와 Top-5 Accuracy를 사용합니다.\n  - 예시: 클래스 10개 중 가장 높은 확률의 Top-1 클래스와 상위 5개 확률의 Top-5 클래스를 판단 기준으로 삼습니다.\n  - Top-1 학습 예측이 가장 잘 맞는 이미지의 확률을 Top-1 Accuracy로, 상위 5개 예측이 잘 맞는 이미지의 확률을 Top-5 Accuracy로 측정합니다.\n  - 일반적으로 에러율 5% 이하(인식률 95% 이상)를 달성하면 분류 능력이 높다고 봅니다. 사람의 인식률과 비교하면 대략 94.9% 수준으로 언급됩니다.\n- 이미지 생성 AI의 벤치마크\n  - 벤치마크로는 STL-10과 CIFAR-10 데이터셋의 프리셰 인셉션 거리(FID)를 사용합니다. FID 점수가 낮을수록 실제와 비슷하다는 뜻으로 성능이 좋다는 판단을 내립니다.\n  - STL-10 기반 KAIST와 서울대의 최신 모델은 FID 약 7.7로, 2018–2020년 모델의 약 25–35 수준에 비해 크게 개선되었습니다.\n  - CIFAR-10 기반 엔비디아 모델은 FID 약 2.2로 과거 대비 큰 향상을 보였습니다.\n  - 주의: CIFAR-10은 STL-10보다 해상도가 낮아 FID 점수가 상대적으로 낮게 나올 수 있고, 두 모델의 절대 성능 비교는 직접적이지 않습니다.\n- 부가 정보\n  - 수치의 출처는 Stanford HAI의 AI Index Report 2022(재편집)이며, 그림 2-2-1은 이미지 생성 AI의 성능 변화를 시각적으로 보여줍니다.\n  - FID의 정의와 해석에 대한 주석(6번, 7번 참조)이 포함되어 있습니다.', 'image_summary': ['이 이미지는 두 줄로 구성된 표이다.\n\n- 열 헤더: Class, Rate\n- 클래스 목록: 비행기, 자동차, 새, 고양이, 사슴, 개, 개구리, 말, 배, 트럭\n- 각 클래스에 대응하는 확률(Rate) 값: 비행기 0.5, 자동차 0.1, 새 0.03, 고양이 0.02, 사슴 0, 개 0.1, 개구리 0, 말 0.2, 배 0.05, 트럭 0\n\n즉, 예시 분류기의 Top-1/Top-5 예측에서 각 클래스에 할당된 확률을 나타낸 표이다.', '이 이미지는 2018년부터 2021년까지 이미지 생성 AI의 성능 변화를 나타내는 FID(Frechet Inception Distance) 점수의 추세선을 보여주는 그래프입니다. \n- y축: FID 점수(값이 낮을수록 성능이 좋음)\n- x축: 연도(2018, 2019, 2020, 2021)\n- 그래프는 해가 지날수록 점수가 점차 낮아지는 하락 추세를 보여주며, 2021년 끝점은 7.71로 표기되어 있습니다.\n- FID는 생성 이미지와 실제 이미지 간의 분포 차이를 측정하는 지표로, 값이 작아질수록 생성 품질이 좋아지는 것을 의미합니다.', '다음은 그림(그림 2-2-1)의 내용 설명입니다.\n\n- 그림 제목/용도: 그림 2-2-1 이미지 생성 AI의 성능 변화. 이미지 생성 AI의 품질을 나타내는 FID(Frechet Inception Distance) 점수의 연도별 변화를 보여주는 선 그래프입니다.\n- 축 및 구성: 가로축은 연도(2017~2021), 세로축은 FID 점수(0~약 30). 점수가 낮을수록 생성된 이미지가 실제 이미지와 더 비슷하다는 것을 의미합니다.\n- 데이터 경향: 2017년 약 30에서 시작해 2018년 약 15로 급격히 감소하고, 2019년 부근에 약 12~13으로 이어진 뒤 2020년대에 3~4로 크게 낮아지며, 2021년에는 약 2.1로 더 떨어지는 경향을 보입니다.\n- 해석 포인트: FID 점수는 낮을수록 실제 이미지와의 차이가 작아지며 구별하기 어려워진다는 의미입니다. FID 0은 완전히 동일한 이미지를 뜻합니다.\n- 요약: 이 그림은 2017년から2021년까지 이미지 생성 AI의 품질이 지속적으로 향상되었음을 시각적으로 보여줍니다.'], 'id': 17, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:18
# {'page': 12, 'image_id': [110, 116, 118], 'image_path': ['/images/SPRI_2022_cropped_table_110.png', '/images/SPRI_2022_cropped_chart_116.png', '/images/SPRI_2022_cropped_chart_118.png'], 'text_summary': '이 글은 이미지 분류와 이미지 생성 AI의 성능 평가 방법 및 최근 벤치마크의 시사점을 정리합니다.\n\n주요 내용 요약\n- 이미지 분류 성능 평가 지표\n  - 보통 Top-1 Accuracy와 Top-5 Accuracy를 사용합니다.\n  - 예시: 클래스 10개 중 가장 높은 확률의 Top-1 클래스와 상위 5개 확률의 Top-5 클래스를 판단 기준으로 삼습니다.\n  - Top-1 학습 예측이 가장 잘 맞는 이미지의 확률을 Top-1 Accuracy로, 상위 5개 예측이 잘 맞는 이미지의 확률을 Top-5 Accuracy로 측정합니다.\n  - 일반적으로 에러율 5% 이하(인식률 95% 이상)를 달성하면 분류 능력이 높다고 봅니다. 사람의 인식률과 비교하면 대략 94.9% 수준으로 언급됩니다.\n- 이미지 생성 AI의 벤치마크\n  - 벤치마크로는 STL-10과 CIFAR-10 데이터셋의 프리셰 인셉션 거리(FID)를 사용합니다. FID 점수가 낮을수록 실제와 비슷하다는 뜻으로 성능이 좋다는 판단을 내립니다.\n  - STL-10 기반 KAIST와 서울대의 최신 모델은 FID 약 7.7로, 2018–2020년 모델의 약 25–35 수준에 비해 크게 개선되었습니다.\n  - CIFAR-10 기반 엔비디아 모델은 FID 약 2.2로 과거 대비 큰 향상을 보였습니다.\n  - 주의: CIFAR-10은 STL-10보다 해상도가 낮아 FID 점수가 상대적으로 낮게 나올 수 있고, 두 모델의 절대 성능 비교는 직접적이지 않습니다.\n- 부가 정보\n  - 수치의 출처는 Stanford HAI의 AI Index Report 2022(재편집)이며, 그림 2-2-1은 이미지 생성 AI의 성능 변화를 시각적으로 보여줍니다.\n  - FID의 정의와 해석에 대한 주석(6번, 7번 참조)이 포함되어 있습니다.', 'image_summary': ['이 이미지는 두 줄로 구성된 표이다.\n\n- 열 헤더: Class, Rate\n- 클래스 목록: 비행기, 자동차, 새, 고양이, 사슴, 개, 개구리, 말, 배, 트럭\n- 각 클래스에 대응하는 확률(Rate) 값: 비행기 0.5, 자동차 0.1, 새 0.03, 고양이 0.02, 사슴 0, 개 0.1, 개구리 0, 말 0.2, 배 0.05, 트럭 0\n\n즉, 예시 분류기의 Top-1/Top-5 예측에서 각 클래스에 할당된 확률을 나타낸 표이다.', '이 이미지는 2018년부터 2021년까지 이미지 생성 AI의 성능 변화를 나타내는 FID(Frechet Inception Distance) 점수의 추세선을 보여주는 그래프입니다. \n- y축: FID 점수(값이 낮을수록 성능이 좋음)\n- x축: 연도(2018, 2019, 2020, 2021)\n- 그래프는 해가 지날수록 점수가 점차 낮아지는 하락 추세를 보여주며, 2021년 끝점은 7.71로 표기되어 있습니다.\n- FID는 생성 이미지와 실제 이미지 간의 분포 차이를 측정하는 지표로, 값이 작아질수록 생성 품질이 좋아지는 것을 의미합니다.', '다음은 그림(그림 2-2-1)의 내용 설명입니다.\n\n- 그림 제목/용도: 그림 2-2-1 이미지 생성 AI의 성능 변화. 이미지 생성 AI의 품질을 나타내는 FID(Frechet Inception Distance) 점수의 연도별 변화를 보여주는 선 그래프입니다.\n- 축 및 구성: 가로축은 연도(2017~2021), 세로축은 FID 점수(0~약 30). 점수가 낮을수록 생성된 이미지가 실제 이미지와 더 비슷하다는 것을 의미합니다.\n- 데이터 경향: 2017년 약 30에서 시작해 2018년 약 15로 급격히 감소하고, 2019년 부근에 약 12~13으로 이어진 뒤 2020년대에 3~4로 크게 낮아지며, 2021년에는 약 2.1로 더 떨어지는 경향을 보입니다.\n- 해석 포인트: FID 점수는 낮을수록 실제 이미지와의 차이가 작아지며 구별하기 어려워진다는 의미입니다. FID 0은 완전히 동일한 이미지를 뜻합니다.\n- 요약: 이 그림은 2017년から2021년까지 이미지 생성 AI의 품질이 지속적으로 향상되었음을 시각적으로 보여줍니다.'], 'id': 18, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:19
# {'page': 13, 'image_id': [136], 'image_path': ['/images/SPRI_2022_cropped_figure_136.png'], 'text_summary': [], 'image_summary': '- 이미지가 가로로 3패널로 구성된 합성 이미지(혹은 딥페이크 예시) 콜라주입니다.\n- 같은 인물이 서로 다른 스포츠 의상을 입고 각각 다른 배경에서 서 있는 모습으로 보입니다.\n  - 왼쪽 패널: 흰색과 노란색이 강조된 유니폼을 입고 관중이 보이는 경기장 배경.\n  - 가운데 패널: 파란색과 빨간색이 강한 스트라이프 의상을 입고 있으며 축구/스포츠 분위기의 밝은 배경. 손에는 공 같은 구체를 들고 있는 듯합니다.\n  - 오른쪽 패널: 흰색 상의와 반바지를 입고 테니스 라켓을 들고 있는 모습으로 테니스 코트 분위기.\n- 세 패널 모두 얼굴에 핑크/자주빛 계열의 격자나 바 같은 오버레이가 있어 얼굴 합성 흔적을 암시하는 디텍션 표식이 보입니다. \n- 인물의 신원은 특정할 수 없으며, 딥페이크/합성 예시를 보여주는 구성으로 보입니다.', 'id': 19, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:20
# {'page': 13, 'image_id': [136], 'image_path': ['/images/SPRI_2022_cropped_figure_136.png'], 'text_summary': [], 'image_summary': '- 이미지가 가로로 3패널로 구성된 합성 이미지(혹은 딥페이크 예시) 콜라주입니다.\n- 같은 인물이 서로 다른 스포츠 의상을 입고 각각 다른 배경에서 서 있는 모습으로 보입니다.\n  - 왼쪽 패널: 흰색과 노란색이 강조된 유니폼을 입고 관중이 보이는 경기장 배경.\n  - 가운데 패널: 파란색과 빨간색이 강한 스트라이프 의상을 입고 있으며 축구/스포츠 분위기의 밝은 배경. 손에는 공 같은 구체를 들고 있는 듯합니다.\n  - 오른쪽 패널: 흰색 상의와 반바지를 입고 테니스 라켓을 들고 있는 모습으로 테니스 코트 분위기.\n- 세 패널 모두 얼굴에 핑크/자주빛 계열의 격자나 바 같은 오버레이가 있어 얼굴 합성 흔적을 암시하는 디텍션 표식이 보입니다. \n- 인물의 신원은 특정할 수 없으며, 딥페이크/합성 예시를 보여주는 구성으로 보입니다.', 'id': 20, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:21
# {'page': 14, 'image_id': [145, 147], 'image_path': ['/images/SPRI_2022_cropped_chart_145.png', '/images/SPRI_2022_cropped_chart_147.png'], 'text_summary': '다음은 주어진 텍스트의 핵심 내용을 간단히 요약한 것입니다.\n\n- 맥락\n  - SPRi 이슈리포트 IS-139는 AI Index 2022의 주요 내용과 시사점을 정리하고 있습니다. 특히 비전 분야의 자세 추정(pose estimation)과 의미 세분화(Semantic Segmentation)의 성능 변화에 주목합니다.\n\n- 자세 추정(2D/3D 포즈 추정)\n  - Leeds Sports Poses 벤치마크: 2014년 80%에서 2021년 99.5%로 크게 향상.\n  - Human3.6M 벤치마크: MPJPE(관절 위치 오차 평균, 단위:mm) 기준으로 성능이 개선되었으나 수치가 다층으로 제시됩니다.\n    - 일반 설명으로는 2013년 약 16 cm에서 2021년 약 1.9 cm 수준까지 개선.\n    - 차트에 제시된 다른 지표로는 평균 오차가 2011년 160 mm에서 2021년 10 mm 내외로 감소하는 추세를 보여줍니다.\n  - 요지: 2010년대 중반 이후 데이터 규모 확대와 모델 성능의 지속적인 개선으로 밀리미터 단위의 자세 추정이 가능해지는 흐름이 뚜렷합니다.\n\n- 의미 세분화(Semantic Segmentation)\n  - Cityscapes 벤치마크에서 2021년 최고 성능 AI 시스템의 IOU(Intersection-Over-Union) 점수는 86.2%로, 2015년 대비 약 14.6pp 상승했습니다.\n  - 의미 세분화는 이미지의 각 픽셀에 범주를 할당하는 작업으로, 자율주행, 의료 영상 등 다양한 분야에서 중요합니다.\n\n- 데이터셋 및 시사점\n  - Leeds Sports Poses: 움직이는 스포츠 선수 이미지 약 2,000장에 14개 관절 정보 포함.\n  - Human3.6M: 17가지 자세 유형에 대한 3D 자세 추정 데이터로, 약 360만 장 이상의 이미지로 구성.\n  - 의미 세분화 데이터: 50개 도시의 계절별 거리 환경 이미지를 포함하며, IOU가 높을수록 세분화 정확도가 높음.\n\n- 결론적 시사점\n  - 2010년대 중반부터 데이터 규모 확충과 모델 개선이 비전 인식 성능의 가파른 상승으로 이어졌으며, 특정 태스크에서 인간 수준에 근접하거나 근접하는 수준의 성능에 도달하는 사례가 늘고 있습니다.\n', 'image_summary': ['해당 이미지는 2014년부터 2021년까지 자세 추정 AI의 “정확한 관절 포인트 비율”(Percentage of Correct Keypoints)의 변화를 나타내는 선 그래프입니다. 축은 y축에 정확한 관절 포인트 비율(0–100%), x축에 연도(2014–2021)를 표시합니다.\n\n주요 내용\n- 2014년 약 80%, 2015년 약 90%, 2016년 약 95%로 지속적으로 상승.\n- 2017년~2020년까지 약 95%를 유지하며 비교적 정체되는 구간.\n- 2021년에 약 99.5%로 크게 상승.\n\n요약하면 초기 빠른 개선 후 2017–2020년대에는 정체되다가 2021년에 다시 큰 폭으로 성능이 향상된 모습을 보여주는 그래프입니다.', '다음 이미지는 SPRI 2022 AI Index Report의 그림 2-2-3에 실린 두 벤치마크의 자세 추정 성능 변화를 보여주는 차트들입니다.\n\n- (a) Leeds Sports Poses 벤치마크\n  - 차트 유형: 선 그래프\n  - 축: 가로축은 연도(2011–2021), 세로축은 평균 MPJPE(단위: mm)\n  - 경향: 2011년 약 160 mm에서 시작해 해를 거듭할수록 감소하다가 2021년에는 약 10–20 mm대까지 낮아진 모습을 보임. 연도별 구체 수치(테이블 표시): 2011 160 mm, 2012 120 mm, 2013 100 mm, 2014 80 mm, 2015 60 mm, 2016 50 mm, 2017 40 mm, 2018 30 mm, 2019 20 mm, 2020 10 mm, 2021 10 mm. 그래프 옆에 2021년 값을 나타내는 표시도 있음(약 23.70 mm 및 18.70 mm로 보이는 주석).\n\n- (b) Human3.6M 벤치마크\n  - 차트 유형: 선 그래프\n  - 축: 가로축은 연도(2011–2021), 세로축은 평균 MPJPE(또는 해당 벤치마크의 유사 지표, 단위 mm)\n  - 경향: 2011년대 초반의 높은 오차로 시작해 해가 지날수록 꾸준히 감소하고, 2021년에는 대략 수십 mm대에서 더 낮아지는 모습. 표의 구간값은 (대략적으로) 2011 160 mm, 2012 120 mm, 2013 100 mm, 2014 80 mm, 2015 60 mm, 2016 50 mm, 2017 40 mm, 2018 30 mm, 2019 20 mm, 2020 10 mm, 2021 10 mm.\n\n전체 요지\n- 두 벤치마크 모두 2011년대에 비해 2021년까지 자세 추정의 평균 오차가 크게 감소해 성능이 크게 향상되었음을 시각적으로 보여줍니다.'], 'id': 21, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:22
# {'page': 14, 'image_id': [145, 147], 'image_path': ['/images/SPRI_2022_cropped_chart_145.png', '/images/SPRI_2022_cropped_chart_147.png'], 'text_summary': '다음은 주어진 텍스트의 핵심 내용을 간단히 요약한 것입니다.\n\n- 맥락\n  - SPRi 이슈리포트 IS-139는 AI Index 2022의 주요 내용과 시사점을 정리하고 있습니다. 특히 비전 분야의 자세 추정(pose estimation)과 의미 세분화(Semantic Segmentation)의 성능 변화에 주목합니다.\n\n- 자세 추정(2D/3D 포즈 추정)\n  - Leeds Sports Poses 벤치마크: 2014년 80%에서 2021년 99.5%로 크게 향상.\n  - Human3.6M 벤치마크: MPJPE(관절 위치 오차 평균, 단위:mm) 기준으로 성능이 개선되었으나 수치가 다층으로 제시됩니다.\n    - 일반 설명으로는 2013년 약 16 cm에서 2021년 약 1.9 cm 수준까지 개선.\n    - 차트에 제시된 다른 지표로는 평균 오차가 2011년 160 mm에서 2021년 10 mm 내외로 감소하는 추세를 보여줍니다.\n  - 요지: 2010년대 중반 이후 데이터 규모 확대와 모델 성능의 지속적인 개선으로 밀리미터 단위의 자세 추정이 가능해지는 흐름이 뚜렷합니다.\n\n- 의미 세분화(Semantic Segmentation)\n  - Cityscapes 벤치마크에서 2021년 최고 성능 AI 시스템의 IOU(Intersection-Over-Union) 점수는 86.2%로, 2015년 대비 약 14.6pp 상승했습니다.\n  - 의미 세분화는 이미지의 각 픽셀에 범주를 할당하는 작업으로, 자율주행, 의료 영상 등 다양한 분야에서 중요합니다.\n\n- 데이터셋 및 시사점\n  - Leeds Sports Poses: 움직이는 스포츠 선수 이미지 약 2,000장에 14개 관절 정보 포함.\n  - Human3.6M: 17가지 자세 유형에 대한 3D 자세 추정 데이터로, 약 360만 장 이상의 이미지로 구성.\n  - 의미 세분화 데이터: 50개 도시의 계절별 거리 환경 이미지를 포함하며, IOU가 높을수록 세분화 정확도가 높음.\n\n- 결론적 시사점\n  - 2010년대 중반부터 데이터 규모 확충과 모델 개선이 비전 인식 성능의 가파른 상승으로 이어졌으며, 특정 태스크에서 인간 수준에 근접하거나 근접하는 수준의 성능에 도달하는 사례가 늘고 있습니다.\n', 'image_summary': ['해당 이미지는 2014년부터 2021년까지 자세 추정 AI의 “정확한 관절 포인트 비율”(Percentage of Correct Keypoints)의 변화를 나타내는 선 그래프입니다. 축은 y축에 정확한 관절 포인트 비율(0–100%), x축에 연도(2014–2021)를 표시합니다.\n\n주요 내용\n- 2014년 약 80%, 2015년 약 90%, 2016년 약 95%로 지속적으로 상승.\n- 2017년~2020년까지 약 95%를 유지하며 비교적 정체되는 구간.\n- 2021년에 약 99.5%로 크게 상승.\n\n요약하면 초기 빠른 개선 후 2017–2020년대에는 정체되다가 2021년에 다시 큰 폭으로 성능이 향상된 모습을 보여주는 그래프입니다.', '다음 이미지는 SPRI 2022 AI Index Report의 그림 2-2-3에 실린 두 벤치마크의 자세 추정 성능 변화를 보여주는 차트들입니다.\n\n- (a) Leeds Sports Poses 벤치마크\n  - 차트 유형: 선 그래프\n  - 축: 가로축은 연도(2011–2021), 세로축은 평균 MPJPE(단위: mm)\n  - 경향: 2011년 약 160 mm에서 시작해 해를 거듭할수록 감소하다가 2021년에는 약 10–20 mm대까지 낮아진 모습을 보임. 연도별 구체 수치(테이블 표시): 2011 160 mm, 2012 120 mm, 2013 100 mm, 2014 80 mm, 2015 60 mm, 2016 50 mm, 2017 40 mm, 2018 30 mm, 2019 20 mm, 2020 10 mm, 2021 10 mm. 그래프 옆에 2021년 값을 나타내는 표시도 있음(약 23.70 mm 및 18.70 mm로 보이는 주석).\n\n- (b) Human3.6M 벤치마크\n  - 차트 유형: 선 그래프\n  - 축: 가로축은 연도(2011–2021), 세로축은 평균 MPJPE(또는 해당 벤치마크의 유사 지표, 단위 mm)\n  - 경향: 2011년대 초반의 높은 오차로 시작해 해가 지날수록 꾸준히 감소하고, 2021년에는 대략 수십 mm대에서 더 낮아지는 모습. 표의 구간값은 (대략적으로) 2011 160 mm, 2012 120 mm, 2013 100 mm, 2014 80 mm, 2015 60 mm, 2016 50 mm, 2017 40 mm, 2018 30 mm, 2019 20 mm, 2020 10 mm, 2021 10 mm.\n\n전체 요지\n- 두 벤치마크 모두 2011년대에 비해 2021년까지 자세 추정의 평균 오차가 크게 감소해 성능이 크게 향상되었음을 시각적으로 보여줍니다.'], 'id': 22, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:23
# {'page': 14, 'image_id': [145, 147], 'image_path': ['/images/SPRI_2022_cropped_chart_145.png', '/images/SPRI_2022_cropped_chart_147.png'], 'text_summary': '다음은 주어진 텍스트의 핵심 내용을 간단히 요약한 것입니다.\n\n- 맥락\n  - SPRi 이슈리포트 IS-139는 AI Index 2022의 주요 내용과 시사점을 정리하고 있습니다. 특히 비전 분야의 자세 추정(pose estimation)과 의미 세분화(Semantic Segmentation)의 성능 변화에 주목합니다.\n\n- 자세 추정(2D/3D 포즈 추정)\n  - Leeds Sports Poses 벤치마크: 2014년 80%에서 2021년 99.5%로 크게 향상.\n  - Human3.6M 벤치마크: MPJPE(관절 위치 오차 평균, 단위:mm) 기준으로 성능이 개선되었으나 수치가 다층으로 제시됩니다.\n    - 일반 설명으로는 2013년 약 16 cm에서 2021년 약 1.9 cm 수준까지 개선.\n    - 차트에 제시된 다른 지표로는 평균 오차가 2011년 160 mm에서 2021년 10 mm 내외로 감소하는 추세를 보여줍니다.\n  - 요지: 2010년대 중반 이후 데이터 규모 확대와 모델 성능의 지속적인 개선으로 밀리미터 단위의 자세 추정이 가능해지는 흐름이 뚜렷합니다.\n\n- 의미 세분화(Semantic Segmentation)\n  - Cityscapes 벤치마크에서 2021년 최고 성능 AI 시스템의 IOU(Intersection-Over-Union) 점수는 86.2%로, 2015년 대비 약 14.6pp 상승했습니다.\n  - 의미 세분화는 이미지의 각 픽셀에 범주를 할당하는 작업으로, 자율주행, 의료 영상 등 다양한 분야에서 중요합니다.\n\n- 데이터셋 및 시사점\n  - Leeds Sports Poses: 움직이는 스포츠 선수 이미지 약 2,000장에 14개 관절 정보 포함.\n  - Human3.6M: 17가지 자세 유형에 대한 3D 자세 추정 데이터로, 약 360만 장 이상의 이미지로 구성.\n  - 의미 세분화 데이터: 50개 도시의 계절별 거리 환경 이미지를 포함하며, IOU가 높을수록 세분화 정확도가 높음.\n\n- 결론적 시사점\n  - 2010년대 중반부터 데이터 규모 확충과 모델 개선이 비전 인식 성능의 가파른 상승으로 이어졌으며, 특정 태스크에서 인간 수준에 근접하거나 근접하는 수준의 성능에 도달하는 사례가 늘고 있습니다.\n', 'image_summary': ['해당 이미지는 2014년부터 2021년까지 자세 추정 AI의 “정확한 관절 포인트 비율”(Percentage of Correct Keypoints)의 변화를 나타내는 선 그래프입니다. 축은 y축에 정확한 관절 포인트 비율(0–100%), x축에 연도(2014–2021)를 표시합니다.\n\n주요 내용\n- 2014년 약 80%, 2015년 약 90%, 2016년 약 95%로 지속적으로 상승.\n- 2017년~2020년까지 약 95%를 유지하며 비교적 정체되는 구간.\n- 2021년에 약 99.5%로 크게 상승.\n\n요약하면 초기 빠른 개선 후 2017–2020년대에는 정체되다가 2021년에 다시 큰 폭으로 성능이 향상된 모습을 보여주는 그래프입니다.', '다음 이미지는 SPRI 2022 AI Index Report의 그림 2-2-3에 실린 두 벤치마크의 자세 추정 성능 변화를 보여주는 차트들입니다.\n\n- (a) Leeds Sports Poses 벤치마크\n  - 차트 유형: 선 그래프\n  - 축: 가로축은 연도(2011–2021), 세로축은 평균 MPJPE(단위: mm)\n  - 경향: 2011년 약 160 mm에서 시작해 해를 거듭할수록 감소하다가 2021년에는 약 10–20 mm대까지 낮아진 모습을 보임. 연도별 구체 수치(테이블 표시): 2011 160 mm, 2012 120 mm, 2013 100 mm, 2014 80 mm, 2015 60 mm, 2016 50 mm, 2017 40 mm, 2018 30 mm, 2019 20 mm, 2020 10 mm, 2021 10 mm. 그래프 옆에 2021년 값을 나타내는 표시도 있음(약 23.70 mm 및 18.70 mm로 보이는 주석).\n\n- (b) Human3.6M 벤치마크\n  - 차트 유형: 선 그래프\n  - 축: 가로축은 연도(2011–2021), 세로축은 평균 MPJPE(또는 해당 벤치마크의 유사 지표, 단위 mm)\n  - 경향: 2011년대 초반의 높은 오차로 시작해 해가 지날수록 꾸준히 감소하고, 2021년에는 대략 수십 mm대에서 더 낮아지는 모습. 표의 구간값은 (대략적으로) 2011 160 mm, 2012 120 mm, 2013 100 mm, 2014 80 mm, 2015 60 mm, 2016 50 mm, 2017 40 mm, 2018 30 mm, 2019 20 mm, 2020 10 mm, 2021 10 mm.\n\n전체 요지\n- 두 벤치마크 모두 2011년대에 비해 2021년까지 자세 추정의 평균 오차가 크게 감소해 성능이 크게 향상되었음을 시각적으로 보여줍니다.'], 'id': 23, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:24
# {'page': 15, 'image_id': [159], 'image_path': ['/images/SPRI_2022_cropped_figure_159.png'], 'text_summary': '다음은 제시된 한국어 텍스트의 요약입니다.\n\n- 주제: AI Index 2022의 시사점 중 의료 영상 분야의 발전과 안면인식 기술의 현황을 다룸.\n\n- 의료 이미지 분할(Medical Image Segmentation)\n  - 정의: 의료 영상에서 장기와 병변/종양 등을 식별하고 분류하는 기술로 의료 서비스 품질에 직접 영향.\n  - 성능 현황: CVC-ClinicDB와 Kvasir-SEG 벤치마크에서 대략 92~94% 수준의 분류 성능.\n  - 구체적 수치:\n    - CVC-ClinicDB: 2021년 기준 대장 용종 인식·분류 94.2%로 2015년 대비 11.9%p 증가.\n    - Kvasir-SEG: 최고 모델의 분류 성능 92.2%로 위장 용종 이미지를 정확하게 분류.\n  - 데이터셋 확산: Kvasir-SEG 활용이 2020년 이전 3개에서 2020년 6개, 2021년 25개로 급증. 의료 이미지 세분화 분야의 급진전 시사.\n\n- 안면인식(Face Detection & Recognition)\n  - 정의: 이미지/비디오에서 개인을 식별하는 기술로, 신원 확인 등에 활용.\n  - 성능 흐름: 최근 상당한 발전으로 인식률이 100%에 가까운 수준에 도달.\n  - 활용 현황: 미국 정부 기관 중 24개 중 18개 기관이 안면인식 기술을 활용하므로 널리 채택 중.\n\n- 부록/데이터셋 주석\n  - CVC-ClinicDB: 31개 대장 내시경 데이터에서 얻은 600여 개의 고해상도 이미지.\n  - Kvasir-SEG: 의사가 수동으로 분할하고 위장병 전문의가 교차 검증한 1,000개의 고해상도 위장 용종 이미지 데이터세트.', 'image_summary': '좌측부터 우측까지 세 패널로 구성된 세분화 예시 이미지입니다.\n\n- 좌측 패널: 실제 사진으로, 도로 위를 달리는 헬멧을 쓴 사람의 오토바이가 보입니다. 배경은 도로와 주변 초목이 보이는 일반적인 현장 이미지입니다.\n\n- 중앙 패널: 같은 이미지를 바탕으로 한 객체 구분(Objects) 맵입니다. 빨간 색으로 경계가 표시된 객체 윤곽이 있고, 내부는 초록·빨강 등으로 객체를 구분한 영역이 보입니다. 즉, 이미지에서 어떤 물체가 어디에 있는지 경계로 표시한 것처럼 보입니다.\n\n- 우측 패널: 각 픽셀을 클래스(Class)별로 색상으로 구분한 분류 맵입니다. 서로 다른 색상으로 라이더/오토바이 등 여러 클래스를 구분해 표현한 모습입니다.', 'id': 24, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:25
# {'page': 15, 'image_id': [159], 'image_path': ['/images/SPRI_2022_cropped_figure_159.png'], 'text_summary': '다음은 제시된 한국어 텍스트의 요약입니다.\n\n- 주제: AI Index 2022의 시사점 중 의료 영상 분야의 발전과 안면인식 기술의 현황을 다룸.\n\n- 의료 이미지 분할(Medical Image Segmentation)\n  - 정의: 의료 영상에서 장기와 병변/종양 등을 식별하고 분류하는 기술로 의료 서비스 품질에 직접 영향.\n  - 성능 현황: CVC-ClinicDB와 Kvasir-SEG 벤치마크에서 대략 92~94% 수준의 분류 성능.\n  - 구체적 수치:\n    - CVC-ClinicDB: 2021년 기준 대장 용종 인식·분류 94.2%로 2015년 대비 11.9%p 증가.\n    - Kvasir-SEG: 최고 모델의 분류 성능 92.2%로 위장 용종 이미지를 정확하게 분류.\n  - 데이터셋 확산: Kvasir-SEG 활용이 2020년 이전 3개에서 2020년 6개, 2021년 25개로 급증. 의료 이미지 세분화 분야의 급진전 시사.\n\n- 안면인식(Face Detection & Recognition)\n  - 정의: 이미지/비디오에서 개인을 식별하는 기술로, 신원 확인 등에 활용.\n  - 성능 흐름: 최근 상당한 발전으로 인식률이 100%에 가까운 수준에 도달.\n  - 활용 현황: 미국 정부 기관 중 24개 중 18개 기관이 안면인식 기술을 활용하므로 널리 채택 중.\n\n- 부록/데이터셋 주석\n  - CVC-ClinicDB: 31개 대장 내시경 데이터에서 얻은 600여 개의 고해상도 이미지.\n  - Kvasir-SEG: 의사가 수동으로 분할하고 위장병 전문의가 교차 검증한 1,000개의 고해상도 위장 용종 이미지 데이터세트.', 'image_summary': '좌측부터 우측까지 세 패널로 구성된 세분화 예시 이미지입니다.\n\n- 좌측 패널: 실제 사진으로, 도로 위를 달리는 헬멧을 쓴 사람의 오토바이가 보입니다. 배경은 도로와 주변 초목이 보이는 일반적인 현장 이미지입니다.\n\n- 중앙 패널: 같은 이미지를 바탕으로 한 객체 구분(Objects) 맵입니다. 빨간 색으로 경계가 표시된 객체 윤곽이 있고, 내부는 초록·빨강 등으로 객체를 구분한 영역이 보입니다. 즉, 이미지에서 어떤 물체가 어디에 있는지 경계로 표시한 것처럼 보입니다.\n\n- 우측 패널: 각 픽셀을 클래스(Class)별로 색상으로 구분한 분류 맵입니다. 서로 다른 색상으로 라이더/오토바이 등 여러 클래스를 구분해 표현한 모습입니다.', 'id': 25, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:26
# {'page': 16, 'image_id': [179, 181, 187], 'image_path': ['/images/SPRI_2022_cropped_chart_179.png', '/images/SPRI_2022_cropped_chart_181.png', '/images/SPRI_2022_cropped_table_187.png'], 'text_summary': '요약\n\n- AI Index 2022의 주요 시사점은 얼굴인식 분야의 성능이 크게 향상되었다는 것. NIST의 FRVT 테스트에서 최고 알고리즘은 오류율 0.1%를 달성했고, 2017년 최고 성능의 오류율이 50%였던 반면, 2021년에는 모든 시스템이 최대 3% 미만의 오류율을 기록했다.\n- 코로나19로 인한 마스크 착용 상황에서도 인식 성능은 떨어지지만, 마스크 비착용 대비 차이는 2019년 이후 좁혀졌다. FNMR(오류가 없는 매칭 실패 비율) 추세는 2019년 3.7%, 2020년 2.3%, 2021년 1.4%로 개선되었다.\n- 시각 추론(Visual Reasoning)은 이미지와 텍스트를 결합해 추론하는 더 발전된 이미지 인식 기술로, 최근 인간에 근접한 성능을 보이고 있다. 예시로 “누가 안경을 쓰고 있는가?” 같은 질문에 대해 이미지와 텍스트를 이용해 답을 도출하는 방식이 제시된다.\n- 시각 추론의 실제 사례와 함께, 얼굴인식, 인신매매 피해자 식별, 여권 중복성 체크, 비자 확인 등을 테스트하며 FNMR이 낮을수록 성능이 우수하다는 점이 강조된다.\n- 자료 출처는 Stanford HAI와 AI Index Report 2022(재편집)이며, 그림 2-2-5와 그림 2-2-6 등 시각 추론 관련 도표와 예시가 첨부되어 있다.', 'image_summary': ['다음 이미지는 2017년부터 2021년까지의 얼굴 인식 AI 성능 변화 추이를 보여 주는 선 그래프입니다.\n\n- 유형: 선형 그래프(여러 색상의 선이 겹쳐 있음)  \n- 축: 가로축은 연도(2017 → 2021), 세로축은 오류율(%) 또는 성능지표의 비율로 보입니다.  \n- 내용: 서로 다른 조건/모델로 추정된 다섯 개의 선이 차례로 감소하는 형태로, 전반적으로 2017년에 비해 2021년에 성능이 크게 개선되었음을 시각화합니다.  \n- 2021년 값 표기: 각 선의 2021년 값이 그래프의 오른쪽에 숫자로 표시되어 있으며, 대략 2.97%, 0.44%, 0.31%, 0.22%, 0.13% 정도로 제시되어 있습니다.  \n- 요지: 2017년 대비 2021년에 오류율이 낮아져 성능이 향상되었음을 보여 줍니다.  \n- 출처: 그림은 SPRI 이슈리포트의 [그림 2-2-5] 안면인식 AI 성능 변화로, 자료는 Stanford HAI, AI Index Report 2022(재편집)로 표기되어 있습니다.', '다음은 이미지의 내용에 대한 한국어 설명입니다.\n\n- 유형: 두 개의 선그래프를 담은 선 그래프로, 2019년부터 2021년까지의 연도별 추세를 보여줍니다.\n- 축:\n  - 가로축(x축): 연도(2019, 2020, 2021).\n  - 세로축(y축): 오류율(%). 값의 범위는 대략 0%에서 3%대 초반 정도로 보입니다.\n- 데이터 시리즈:\n  - 파란색 선: FNMR(False Non-Match Rate, 실제 다른 사람인데 매칭되지 않는 오류)의 추세를 나타냅니다. 2019년 약 3.7%에서 시작해 2020년 약 2.3%, 2021년 약 1.4%로 감소하며 성능이 개선되었습니다.\n  - 보라색 선: FMR(False Match Rate, 잘못 매칭되는 오탐률)의 추세를 나타냅니다. 연도별로 대체로 0.2%~0.3%대에서 비교적 평탄하게 유지되며 큰 변화가 없었습니다.\n- 의미: FNMR은 낮아질수록 성능이 우수하다는 점을 시사하고, FMR은 아주 낮고 안정적인 수준을 유지하는 흐름으로 해석됩니다.\n- 그림 정보: 그림 제목은 "그림 2-2-5 안면인식 AI 성능 변화"로 보이며, FP/오류율이 낮아질수록 성능이 향상된다는 맥락의 다이어그램입니다.', '다음 내용을 담은 표 이미지입니다.\n\n- 질문(Text): “누가 안경을 쓰고 있는가?”\n- 제시사진: 왼쪽과 오른쪽에 각각 사진이 두 장 제시되어 있다.\n  - 왼쪽 사진: 안경을 쓴 남성이 보이는 사진(다른 인물이 옆에 함께 보임).\n  - 오른쪽 사진: 커플의 사진으로 보이며, 안경을 쓰고 있는 인물이 누구인지에 대한 사진.\n- AI 답변: 왼쪽 사진은 “남성”, 오른쪽 사진은 “여성”으로 안경 착용자를 판단한 결과를 보여준다.\n\n요약하면, 두 사진에서 각각 안경을 쓴 사람의 성별 추정 결과가 “남성”과 “여성”으로 제시되어 있는 콘텐츠입니다.'], 'id': 26, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:27
# {'page': 16, 'image_id': [179, 181, 187], 'image_path': ['/images/SPRI_2022_cropped_chart_179.png', '/images/SPRI_2022_cropped_chart_181.png', '/images/SPRI_2022_cropped_table_187.png'], 'text_summary': '요약\n\n- AI Index 2022의 주요 시사점은 얼굴인식 분야의 성능이 크게 향상되었다는 것. NIST의 FRVT 테스트에서 최고 알고리즘은 오류율 0.1%를 달성했고, 2017년 최고 성능의 오류율이 50%였던 반면, 2021년에는 모든 시스템이 최대 3% 미만의 오류율을 기록했다.\n- 코로나19로 인한 마스크 착용 상황에서도 인식 성능은 떨어지지만, 마스크 비착용 대비 차이는 2019년 이후 좁혀졌다. FNMR(오류가 없는 매칭 실패 비율) 추세는 2019년 3.7%, 2020년 2.3%, 2021년 1.4%로 개선되었다.\n- 시각 추론(Visual Reasoning)은 이미지와 텍스트를 결합해 추론하는 더 발전된 이미지 인식 기술로, 최근 인간에 근접한 성능을 보이고 있다. 예시로 “누가 안경을 쓰고 있는가?” 같은 질문에 대해 이미지와 텍스트를 이용해 답을 도출하는 방식이 제시된다.\n- 시각 추론의 실제 사례와 함께, 얼굴인식, 인신매매 피해자 식별, 여권 중복성 체크, 비자 확인 등을 테스트하며 FNMR이 낮을수록 성능이 우수하다는 점이 강조된다.\n- 자료 출처는 Stanford HAI와 AI Index Report 2022(재편집)이며, 그림 2-2-5와 그림 2-2-6 등 시각 추론 관련 도표와 예시가 첨부되어 있다.', 'image_summary': ['다음 이미지는 2017년부터 2021년까지의 얼굴 인식 AI 성능 변화 추이를 보여 주는 선 그래프입니다.\n\n- 유형: 선형 그래프(여러 색상의 선이 겹쳐 있음)  \n- 축: 가로축은 연도(2017 → 2021), 세로축은 오류율(%) 또는 성능지표의 비율로 보입니다.  \n- 내용: 서로 다른 조건/모델로 추정된 다섯 개의 선이 차례로 감소하는 형태로, 전반적으로 2017년에 비해 2021년에 성능이 크게 개선되었음을 시각화합니다.  \n- 2021년 값 표기: 각 선의 2021년 값이 그래프의 오른쪽에 숫자로 표시되어 있으며, 대략 2.97%, 0.44%, 0.31%, 0.22%, 0.13% 정도로 제시되어 있습니다.  \n- 요지: 2017년 대비 2021년에 오류율이 낮아져 성능이 향상되었음을 보여 줍니다.  \n- 출처: 그림은 SPRI 이슈리포트의 [그림 2-2-5] 안면인식 AI 성능 변화로, 자료는 Stanford HAI, AI Index Report 2022(재편집)로 표기되어 있습니다.', '다음은 이미지의 내용에 대한 한국어 설명입니다.\n\n- 유형: 두 개의 선그래프를 담은 선 그래프로, 2019년부터 2021년까지의 연도별 추세를 보여줍니다.\n- 축:\n  - 가로축(x축): 연도(2019, 2020, 2021).\n  - 세로축(y축): 오류율(%). 값의 범위는 대략 0%에서 3%대 초반 정도로 보입니다.\n- 데이터 시리즈:\n  - 파란색 선: FNMR(False Non-Match Rate, 실제 다른 사람인데 매칭되지 않는 오류)의 추세를 나타냅니다. 2019년 약 3.7%에서 시작해 2020년 약 2.3%, 2021년 약 1.4%로 감소하며 성능이 개선되었습니다.\n  - 보라색 선: FMR(False Match Rate, 잘못 매칭되는 오탐률)의 추세를 나타냅니다. 연도별로 대체로 0.2%~0.3%대에서 비교적 평탄하게 유지되며 큰 변화가 없었습니다.\n- 의미: FNMR은 낮아질수록 성능이 우수하다는 점을 시사하고, FMR은 아주 낮고 안정적인 수준을 유지하는 흐름으로 해석됩니다.\n- 그림 정보: 그림 제목은 "그림 2-2-5 안면인식 AI 성능 변화"로 보이며, FP/오류율이 낮아질수록 성능이 향상된다는 맥락의 다이어그램입니다.', '다음 내용을 담은 표 이미지입니다.\n\n- 질문(Text): “누가 안경을 쓰고 있는가?”\n- 제시사진: 왼쪽과 오른쪽에 각각 사진이 두 장 제시되어 있다.\n  - 왼쪽 사진: 안경을 쓴 남성이 보이는 사진(다른 인물이 옆에 함께 보임).\n  - 오른쪽 사진: 커플의 사진으로 보이며, 안경을 쓰고 있는 인물이 누구인지에 대한 사진.\n- AI 답변: 왼쪽 사진은 “남성”, 오른쪽 사진은 “여성”으로 안경 착용자를 판단한 결과를 보여준다.\n\n요약하면, 두 사진에서 각각 안경을 쓴 사람의 성별 추정 결과가 “남성”과 “여성”으로 제시되어 있는 콘텐츠입니다.'], 'id': 27, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:28
# {'page': 17, 'image_id': [], 'image_path': [], 'text_summary': '다음은 제시된 내용의 간단한 요약입니다.\n\n- 시각적 질문 응답(VQA): AI의 성능이 2015년 55.4%에서 2021년 79.8%로 향상되어 인간 수준인 80.8%에 근접했습니다.\n- 비디오 동작 인식(Activity Recognition): MTV가 Kinectics 벤치마크에서 82~89%대의 정확도를 달성합니다. 2022년 1월 발표된 MTV는 Kinectics 600에서 Top-1 89.6%, 400에서 89.1%, 700에서 82.2%의 정확도를 기록했습니다. MTV는 구글, 미시간주립대, 브라운대가 공동 개발한 모델입니다.\n- 언어 및 음성 인식(NLP):\n  - 언어 이해: SS-MoE 모델이 SuperGLUE에서 인간 수준(89.8)을 넘는 91.0점을 달성했습니다.\n  - 독해 성능: SQuAD v1.1은 95.72점, v2.0은 93.21점으로 각각 인간(91.2, 89.5)을 능가했습니다.\n- 부록/데이터셋 관련 참고:\n  - Kinectics 데이터셋은 유튜브의 고품질 비디오 약 65만 편으로 구성되며 400/600/700개의 범주를 테스트합니다. 예/아니오 답변, 인과 관계 식별, 상식 이해 등 8가지 기준으로 평가합니다.\n  - SQuAD는 약 107,000개의 질의응답으로 구성되며, 후속 버전(v2.0)에는 답이 없는 질문 5만 개가 포함되어 더 어려운 읽기 이해를 요구합니다.', 'image_summary': [], 'id': 28, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:29
# {'page': 17, 'image_id': [], 'image_path': [], 'text_summary': '다음은 제시된 내용의 간단한 요약입니다.\n\n- 시각적 질문 응답(VQA): AI의 성능이 2015년 55.4%에서 2021년 79.8%로 향상되어 인간 수준인 80.8%에 근접했습니다.\n- 비디오 동작 인식(Activity Recognition): MTV가 Kinectics 벤치마크에서 82~89%대의 정확도를 달성합니다. 2022년 1월 발표된 MTV는 Kinectics 600에서 Top-1 89.6%, 400에서 89.1%, 700에서 82.2%의 정확도를 기록했습니다. MTV는 구글, 미시간주립대, 브라운대가 공동 개발한 모델입니다.\n- 언어 및 음성 인식(NLP):\n  - 언어 이해: SS-MoE 모델이 SuperGLUE에서 인간 수준(89.8)을 넘는 91.0점을 달성했습니다.\n  - 독해 성능: SQuAD v1.1은 95.72점, v2.0은 93.21점으로 각각 인간(91.2, 89.5)을 능가했습니다.\n- 부록/데이터셋 관련 참고:\n  - Kinectics 데이터셋은 유튜브의 고품질 비디오 약 65만 편으로 구성되며 400/600/700개의 범주를 테스트합니다. 예/아니오 답변, 인과 관계 식별, 상식 이해 등 8가지 기준으로 평가합니다.\n  - SQuAD는 약 107,000개의 질의응답으로 구성되며, 후속 버전(v2.0)에는 답이 없는 질문 5만 개가 포함되어 더 어려운 읽기 이해를 요구합니다.', 'image_summary': [], 'id': 29, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:30
# {'page': 18, 'image_id': [209, 211], 'image_path': ['/images/SPRI_2022_cropped_chart_209.png', '/images/SPRI_2022_cropped_chart_211.png'], 'text_summary': '다음은 주어진 텍스트의 요약입니다.\n\n- 주제: SPRi 이슈리포트 IS-139의 AI Index 2022 주요 내용 및 시사점\n- 주요 내용 요약\n  - SS-MoE의 SuperGLUE 벤치마크\n    - 2019년 79.8%, 2020년 97.9%, 2021년 100.8%로 급격히 상승(또 다른 표시는 2016년~2021년 간의 지속적 상승: 80.3% → 95.72%).\n  - SQuAD의 성능 변화\n    - 언어 이해 성능이 지속적으로 향상되고 있음(구체 수치는 그림 참조).\n  - 문서 요약(Text Summarization)\n    - 과거 대비 성능 향상은 있으나 최근 속도는 정체.\n    - ROUGE 기준으로 약 15%p 정도의 향상.\n    - 벤치마크별 증가 예시: ArXiv 벤치마크는 2017년 약 32%에서 47.1%로, PubMed 벤치마크는 2017년 34.6%에서 48.2%로 상승.\n  - 자연어 추론(Natural Language Inference)\n    - 전제가 주어졌을 때 가설의 참/거짓/중립을 판단하는 기술로 성능은 향상되었으나 여전히 인간 수준에 미달.\n    - EFL(추론 엔진)은 SNLI 벤치에서 93.1% 달성.\n    - ANLI 기준으로 2021년 최신 성능은 91.87%로 2019년 대비 약 7.7pp 증가했으나 인간 수준(≈92.9%)에는 미치지 못함.\n  - 데이터세트 설명(footnotes)\n    - SNLI, ArXiv, PubMed, ANLI 등 관련 데이터세트의 간단한 설명과 정의가 부록으로 제시됨.\n\n- 시사점\n  - 전반적으로 벤치마크 성능은 개선되고 있지만, 인간 수준에 도달하기까지는 여전히 격차가 존재하고, 문서 요약의 속도도 다소 정체되는 경향이 있음.', 'image_summary': ['다음 그림은 연도별 SQuAD(언어 이해 AI 성능) 변화 추이를 보여주는 선 그래프입니다.\n\n- 축: 가로축은 2019, 2020, 2021년, 세로축은 성능(%, 대략 80%~100% 범위).\n- 데이터 포인트: 2019년 약 89.8%, 2020년 약 90~91%, 2021년 약 91.6% 정도로 점진적으로 상승.\n- 보조선: 그래프에 보라색 점선으로 구성된 기준선이 수평으로 그려져 있습니다(대략 89% 부근).\n- 요지: 성능이 해마다 소폭 증가하나 인간 수준에 도달하진 못한 전형적인 추세를 보이고 있습니다.', '다음 그림은 언어 이해 AI의 성능 변화를 보여 주는 선 그래프입니다.\n\n- 제목/참조: 그림 2-2-6 언어 이해 AI 성능 변화\n- 축 정보: x축은 연도(2016–2021), y축은 성능 지표(대략 80%~105% 범위)\n- 두 개의 선: Squad 1.0과 Squad 2.0을 나타내는 선\n- 경향: 두 선 모두 시간이 지남에 따라 상승하는 추세를 보이며, 2021년에는 Squad 2.0이 Squad 1.0보다 높음\n- 최종 값(2021년 근처): Squad 1.0 약 85.97%, Squad 2.0 약 89.3% 수준으로 표시\n\n요약하면, SQuAD 성능은 2016년대 중반에서 꾸준히 상승했고, 2021년에는 Squad 2.0이 Squad 1.0보다 높은 성능을 기록하고 있습니다.'], 'id': 30, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:31
# {'page': 18, 'image_id': [209, 211], 'image_path': ['/images/SPRI_2022_cropped_chart_209.png', '/images/SPRI_2022_cropped_chart_211.png'], 'text_summary': '다음은 주어진 텍스트의 요약입니다.\n\n- 주제: SPRi 이슈리포트 IS-139의 AI Index 2022 주요 내용 및 시사점\n- 주요 내용 요약\n  - SS-MoE의 SuperGLUE 벤치마크\n    - 2019년 79.8%, 2020년 97.9%, 2021년 100.8%로 급격히 상승(또 다른 표시는 2016년~2021년 간의 지속적 상승: 80.3% → 95.72%).\n  - SQuAD의 성능 변화\n    - 언어 이해 성능이 지속적으로 향상되고 있음(구체 수치는 그림 참조).\n  - 문서 요약(Text Summarization)\n    - 과거 대비 성능 향상은 있으나 최근 속도는 정체.\n    - ROUGE 기준으로 약 15%p 정도의 향상.\n    - 벤치마크별 증가 예시: ArXiv 벤치마크는 2017년 약 32%에서 47.1%로, PubMed 벤치마크는 2017년 34.6%에서 48.2%로 상승.\n  - 자연어 추론(Natural Language Inference)\n    - 전제가 주어졌을 때 가설의 참/거짓/중립을 판단하는 기술로 성능은 향상되었으나 여전히 인간 수준에 미달.\n    - EFL(추론 엔진)은 SNLI 벤치에서 93.1% 달성.\n    - ANLI 기준으로 2021년 최신 성능은 91.87%로 2019년 대비 약 7.7pp 증가했으나 인간 수준(≈92.9%)에는 미치지 못함.\n  - 데이터세트 설명(footnotes)\n    - SNLI, ArXiv, PubMed, ANLI 등 관련 데이터세트의 간단한 설명과 정의가 부록으로 제시됨.\n\n- 시사점\n  - 전반적으로 벤치마크 성능은 개선되고 있지만, 인간 수준에 도달하기까지는 여전히 격차가 존재하고, 문서 요약의 속도도 다소 정체되는 경향이 있음.', 'image_summary': ['다음 그림은 연도별 SQuAD(언어 이해 AI 성능) 변화 추이를 보여주는 선 그래프입니다.\n\n- 축: 가로축은 2019, 2020, 2021년, 세로축은 성능(%, 대략 80%~100% 범위).\n- 데이터 포인트: 2019년 약 89.8%, 2020년 약 90~91%, 2021년 약 91.6% 정도로 점진적으로 상승.\n- 보조선: 그래프에 보라색 점선으로 구성된 기준선이 수평으로 그려져 있습니다(대략 89% 부근).\n- 요지: 성능이 해마다 소폭 증가하나 인간 수준에 도달하진 못한 전형적인 추세를 보이고 있습니다.', '다음 그림은 언어 이해 AI의 성능 변화를 보여 주는 선 그래프입니다.\n\n- 제목/참조: 그림 2-2-6 언어 이해 AI 성능 변화\n- 축 정보: x축은 연도(2016–2021), y축은 성능 지표(대략 80%~105% 범위)\n- 두 개의 선: Squad 1.0과 Squad 2.0을 나타내는 선\n- 경향: 두 선 모두 시간이 지남에 따라 상승하는 추세를 보이며, 2021년에는 Squad 2.0이 Squad 1.0보다 높음\n- 최종 값(2021년 근처): Squad 1.0 약 85.97%, Squad 2.0 약 89.3% 수준으로 표시\n\n요약하면, SQuAD 성능은 2016년대 중반에서 꾸준히 상승했고, 2021년에는 Squad 2.0이 Squad 1.0보다 높은 성능을 기록하고 있습니다.'], 'id': 31, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:32
# {'page': 19, 'image_id': [233], 'image_path': ['/images/SPRI_2022_cropped_chart_233.png'], 'text_summary': '다음은 주어진 텍스트의 요약입니다.\n\n- 감성 분석\n  - 자연어처리로 문장의 긍정/부정/중립 등의 감정을 식별하는 기술이 확산 중이며, 고객 응대, 리뷰, 현장 설문 등에 상업적으로 활용이 확대되고 있음.\n  - SemEval21 벤치마크 기준으로 성능이 2015년 약 70%에서 발전해, 중국의 Linklogis와 SCNU의 엔진이 88.64%를 달성.\n  - 평가 데이터로는 7,686개의 레스토랑 및 노트북 고객 리뷰 데이터세트를 사용해 성능을 측정.\n  \n- 기계 번역\n  - 다국어를 번역하는 기술로, 2017년부터 신경망 도입으로 성능이 향상되었으며 검색엔진 및 SNS에서 널리 활용 중.\n  - WMT2014 벤치마크에서 영어-프랑스 번역 BLEU 43.95점(2014년 대비 23.7% 증가), 영어-독일어 35.14점(68.1% 증가)로 크게 개선.\n  - 상업 분야에서 구글 번역 등의 서비스가 2017년 이후 5배 이상 증가.\n  - 그림 2-2-8에 따르면 번역 인공지능의 증가 추이는 2017년 5월 9개에서 2021년 10월 44개 independent MT 서비스로 확장.\n  - 성능 평가는 BLEU 점수로, 출처는 Stanford HAI와 AI Index Report 2022.\n\n요지: 감성 분석과 기계 번역 기술이 동시에 발전했고, 상업적 활용이 확산되며, MT 서비스의 수가 크게 증가하고 있는 추세가 제시되어 있습니다.', 'image_summary': '다음 내용의 이미지입니다:\n\n- 제목/주제: 번역 AI의 증가 추이\n- 형식: 누적 막대그래프 (Stacked bar chart)\n- 축\n  - 가로축(x): 시간 흐름 (05/2017, 07/2017, 11/2017, 03/2018, 07/2018, 12/2018, 06/2019, 11/2019, 07/2020, 10/2021)\n  - 세로축(y): 독립 번역 서비스의 수\n- 구성: 막대가 세 가지 색으로 구성된 누적 막대(bar stack)\n  - 중앙집중형(Centralized)\n  - 오픈소스 사전학습(Open Source Pre-trained)\n  - 프리뷰(Preview)\n- 수치: 각 시점의 막대 위에 총합이 숫자로 표시\n  - 예: 05/2017 ≈ 9, 07/2017 ≈ 10, 11/2017 ≈ 12, 03/2018 ≈ 13, 07/2018 ≈ 16, 12/2018 ≈ 21, 06/2019 ≈ 23, 11/2019 ≈ 26, 07/2020 ≈ 34, 10/2021 ≈ 46\n- 요지: 시간에 따라 독립적인 기계 번역 서비스의 수가 꾸준히 증가하고 있음을 보여줌.\n- 출처: Stanford HAI, AI Index Report 2022의 그림 2-2-8\n\n간단히 말해, 2017년부터 2021년까지 독립 번역 서비스의 수가 지속적으로 증가하는 추세를 색상 구분된 세 부문으로 누적해서 나타낸 그래프입니다.', 'id': 32, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:33
# {'page': 19, 'image_id': [233], 'image_path': ['/images/SPRI_2022_cropped_chart_233.png'], 'text_summary': '다음은 주어진 텍스트의 요약입니다.\n\n- 감성 분석\n  - 자연어처리로 문장의 긍정/부정/중립 등의 감정을 식별하는 기술이 확산 중이며, 고객 응대, 리뷰, 현장 설문 등에 상업적으로 활용이 확대되고 있음.\n  - SemEval21 벤치마크 기준으로 성능이 2015년 약 70%에서 발전해, 중국의 Linklogis와 SCNU의 엔진이 88.64%를 달성.\n  - 평가 데이터로는 7,686개의 레스토랑 및 노트북 고객 리뷰 데이터세트를 사용해 성능을 측정.\n  \n- 기계 번역\n  - 다국어를 번역하는 기술로, 2017년부터 신경망 도입으로 성능이 향상되었으며 검색엔진 및 SNS에서 널리 활용 중.\n  - WMT2014 벤치마크에서 영어-프랑스 번역 BLEU 43.95점(2014년 대비 23.7% 증가), 영어-독일어 35.14점(68.1% 증가)로 크게 개선.\n  - 상업 분야에서 구글 번역 등의 서비스가 2017년 이후 5배 이상 증가.\n  - 그림 2-2-8에 따르면 번역 인공지능의 증가 추이는 2017년 5월 9개에서 2021년 10월 44개 independent MT 서비스로 확장.\n  - 성능 평가는 BLEU 점수로, 출처는 Stanford HAI와 AI Index Report 2022.\n\n요지: 감성 분석과 기계 번역 기술이 동시에 발전했고, 상업적 활용이 확산되며, MT 서비스의 수가 크게 증가하고 있는 추세가 제시되어 있습니다.', 'image_summary': '다음 내용의 이미지입니다:\n\n- 제목/주제: 번역 AI의 증가 추이\n- 형식: 누적 막대그래프 (Stacked bar chart)\n- 축\n  - 가로축(x): 시간 흐름 (05/2017, 07/2017, 11/2017, 03/2018, 07/2018, 12/2018, 06/2019, 11/2019, 07/2020, 10/2021)\n  - 세로축(y): 독립 번역 서비스의 수\n- 구성: 막대가 세 가지 색으로 구성된 누적 막대(bar stack)\n  - 중앙집중형(Centralized)\n  - 오픈소스 사전학습(Open Source Pre-trained)\n  - 프리뷰(Preview)\n- 수치: 각 시점의 막대 위에 총합이 숫자로 표시\n  - 예: 05/2017 ≈ 9, 07/2017 ≈ 10, 11/2017 ≈ 12, 03/2018 ≈ 13, 07/2018 ≈ 16, 12/2018 ≈ 21, 06/2019 ≈ 23, 11/2019 ≈ 26, 07/2020 ≈ 34, 10/2021 ≈ 46\n- 요지: 시간에 따라 독립적인 기계 번역 서비스의 수가 꾸준히 증가하고 있음을 보여줌.\n- 출처: Stanford HAI, AI Index Report 2022의 그림 2-2-8\n\n간단히 말해, 2017년부터 2021년까지 독립 번역 서비스의 수가 지속적으로 증가하는 추세를 색상 구분된 세 부문으로 누적해서 나타낸 그래프입니다.', 'id': 33, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:34
# {'page': 20, 'image_id': [], 'image_path': [], 'text_summary': '다음은 제시된 텍스트의 핵심 내용을 간단히 요약한 것입니다.\n\n- ⑥ 연설·음성 인식\n  - 음성 인식은 말소리를 텍스트로 변환하는 기술로, 딥러닝의 발전으로 최근 크게 향상됨.\n  - 예시로 MIT와 구글의 음성 엔진 W2V-BERT가 LibriSpeech 벤치마크에서 2%의 오류율을 달성(2015년 13.5% 대비 큰 개선).\n  - VoxCeleb 벤치마크 기준으로 최신 시스템의 오류율은 2017년 7.8%에서 2021년 0.42%로 크게 감소해 성능이 크게 향상됨.\n  - LibriSpeech(참고 23): 1000시간 규모의 영어 오디오북 데이터셋으로 고품질/저품질 음성 테스트 및 오류율 표기.\n  - VoxCeleb(참고 24): 대규모 화자 인식 시청각 데이터셋으로 특정 음성을 추출·인식하며 오류율로 성능을 측정.\n\n- 3. 추천 알고리즘\n  - 추천 알고리즘은 사용자가 관심 가질 만한 항목을 제안하는 기술로 상용 플랫폼에서 활발히 활용됨(예: Amazon, Netflix, Spotify, YouTube).\n  - MovieLens 20M 데이터셋(약 2천만 개의 평가)을 이용한 평가에서 2018년 대비 약 5.2%의 향상.\n  - Criteo의 웹사이트 클릭율 예측도 2016년 대비 약 1.8% 향상되며 느리지만 꾸준히 개선.\n\n- 4. 강화 학습\n  - 강화 학습은 에이전트가 이전 학습에 대한 보상으로 학습을 최적화하는 기술로, 응용 및 파급효과가 큼.\n  - 지난 10년간 체스, 바둑, 비디오 게임 등에서 성능이 크게 향상되었고, 앞으로 보다 일반적인 영역으로 확산될 것으로 예상.\n\n요약의 핵심 메시지:\n- 음성 인식은 딥러닝으로 대폭 성능이 개선되었고, 벤치마크에서의 오류율이 크게 감소하고 있음.\n- 추천 알고리즘은 상용 시스템에서 이미 널리 사용되며, 데이터셋 기반의 성능도 꾸준히 개선 중.\n- 강화 학습은 보상 기반 학습으로 다양한 영역에서 성능이 향상되고 있으며, 더 넓은 영역으로 확산될 전망.', 'image_summary': [], 'id': 34, 'title': 'SPRI_2022', 'category': 'AI-index', 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재']}
# Indexed: doc_id:35
# ...
# Indexed: doc_id:497
# {'page': 40, 'image_id': [406, 411], 'image_path': ['/images/SPRI_is_213_cropped_table_406.png', '/images/SPRI_is_213_cropped_table_411.png'], 'text_summary': '다음은 제시된 텍스트의 간략한 요약입니다.\n\n- 본문은 SPRi 이슈리포트 IS-213의 일부로, 디지털 미래기술 전망 2026의 흐름을 다루며 데이터 속 징후를 통해 미래의 실루엣을 제시합니다.\n- 부표 7은 ‘차세대 계산 인텔리전스 및 양자 강화 재료 발견’ 기술군의 전이 흐름 추적 결과를 제시합니다. 2016년부터 2025년까지 연도별로 기술 클러스터명이 나열되어 있으며, 2025년의 최종 기술군은 차세대 계산 인텔리전스 및 양자 강화 재료 발견으로 마무리됩니다.\n  - 대표 흐름 예: 2016년 자동 얼굴 인식 및 영상 검색 시스템 → 2017년 모바일 얼굴 인식 및 활동 추적 시스템 → 2018년 실시간 착용형 제스처 인식 시스템 → 2019년 스마트 도시 이동성 모니터링 시스템 → 2020년 스마트 도시 이동성 예측 시스템 → 2021년 데이터 기반 검색 시스템 → 2022년 클라우드 기반 분산 데이터 처리 시스템 → 2023년 오픈 데이터 분석 플랫폼 → 2024년 대규모 합성 데이터 관리 시스템 → 2025년 차세대 계산 인텔리전스 및 양자 강화 재료 발견.\n- 3. 약신호 3: 뇌-컴퓨터 인터페이스를 다루며, 계보의 전이 흐름에서 4대 주요 기술군은 AI-인간 협력 인텔리전스 시스템, 자율형 고숙련 조작 인텔리전스, 다중모달 AI 영상 시스템, 지능형 교통 예측 및 자율주행 시스템으로 요약됩니다.\n- 부표 8은 ‘AI-인간 협력 인텔리전스 시스템’의 기술군 전이 흐름 추적 결과를 제시합니다. 2021년 F2021_19부터 시작하여 2025년까지의 흐름은:\n  - 2021년: 인간-로봇 상호작용을 위한 가상 현실 기반 학습 시스템\n  - 2022년: 인공지능 기반 가상 현실 교육 시스템\n  - 2023년: 설명 가능한 인공지능 시스템 설계 기술\n  - 2024년: 설명 가능한 인공지능 시스템 개발 기술\n  - 2025년: AI-인간 협력 인텔리전스 시스템\n- 참고로 본문 내 이미지가 삽입되어 있으며, 출처는 저자 작성으로 표기되어 있습니다.', 'image_summary': ['이미지는 F2016_26 흐름ID의 기술 클러스터 전이 흐름을 담은 표로, 2016년부터 2025년까지의 연도별 기술 명칭을 나열하고 있습니다. 출처는 저자 작성으로 표시되어 있습니다.\n\n연도별 기술 클러스터명\n- 2016: 자동 얼굴 인식 및 영상 검색 시스템\n- 2017: 모바일 얼굴 인식 및 활동 추적 시스템\n- 2018: 실시간 착용형 제스처 인식 시스템\n- 2019: 스마트 도시 이동성 모니터링 시스템\n- 2020: 스마트 도시 이동성 예측 시스템\n- 2021: 데이터 기반 검색 시스템\n- 2022: 클라우드 기반 분산 데이터 처리 시스템\n- 2023: 오픈 데이터 분석 플랫폼\n- 2024: 대규모 합성 데이터 관리 시스템\n- 2025: 차세대 계산 인텔리전스 및 양자 강화 재료 발견', '이미지 내용 요약:\n\n- 이미지에는 [부표 8]의 표가 담겨 있으며, 제목은 "AI-인간 협력 인텔리전스 시스템 기술군 전이 흐름의 추적 결과"입니다.\n- 표의 열은 세 가지: flow_id, 연도, 기술 클러스터명.\n- 내용은 F2021_19 흐름으로 2021년부터 2025년까지의 연도별 기술 클러스터명을 나열한 것입니다.\n- 각 연도별 항목은 다음과 같습니다.\n  - 2021년: 인간-로봇 상호작용을 위한 가상 현실 기반 학습 시스템\n  - 2022년: 인공지능 기반 가상 현실 교육 시스템\n  - 2023년: 설명 가능한 인공지능 시스템 설계 기술\n  - 2024년: 설명 가능한 인공지능 시스템 개발 기술\n  - 2025년: AI-인간 협력 인텔리전스 시스템\n- 이 표는 2021년의 flow_id만 F2021_19로 표시되어 있으며, 이후 연도에 대한 항목은 연도만 표기되어 있습니다.'], 'id': 72, 'title': 'SPRI_is_213', 'category': 'issue-report', 'tag': ['미래기술', '산업전망', 'AI스타트업', 'AI인재']}
# Indexed: doc_id:498
# {'page': 41, 'image_id': [417, 420, 423], 'image_path': ['/images/SPRI_is_213_cropped_table_417.png', '/images/SPRI_is_213_cropped_table_420.png', '/images/SPRI_is_213_cropped_table_423.png'], 'text_summary': '다음은 제공된 텍스트의 간단한 요약입니다.\n\n- 본 문서는 SPRi 이슈리포트 IS-213의 일부로, 2대 주요 기술군의 기술 전이 흐름을 연도별로 정리한 표를 제시합니다.\n- 부표 9: 자율형 고숙련 조작 인텔리전스 기술 전이 흐름\n  - 연도에 따른 기술 클러스터 변화가 제시됩니다(예: 2023년 “로봇 조작을 위한 강화 학습 기반 기술”, 2024년 “심층 강화 학습 기반 로봇 조작 시스템”, 2025년 “자율형 고숙련 조작 인텔리전스”).\n- 부표 10: 다중모달 AI 영상 시스템 기술군 전이 흐름\n  - 2019년부터 2025년까지의 흐름을 연도별로 정리합니다. 예: 2019년 “비주얼 질문 응답 시스템”에서 시작해 2025년엔 “다중모달 AI 영상 시스템”으로 귀결하는 흐름이 제시됩니다.\n- 부표 11: 지능형 교통 예측 및 자율주행 시스템 기술 전이 흐름\n  - 2021년부터 2025년까지의 흐름이 연도별로 제시됩니다. 예: 2021년 “사회적 네트워크 동적 군집 탐지 기술”에서 시작해 2025년엔 “지능형 교통 예측 및 자율주행 시스템”으로 확장됩니다.\n- 총평: 각 표의 흐름은 특정 연도에 대응하는 기술 클러스터를 따라 기술 전이의 경로를 보여주며, 출처는 저자 작성으로 표기됩니다.\n- 4. 약신호 4: 분산 AI 얼라인먼트 섹션은 관찰 기간 동안 추적된 주요 기술군으로 다중 에이전트 자율 시스템을 언급하고 있으며, 페이지 표기로 보아 문서의 특정 부분(35쪽)에서 다루어집니다.', 'image_summary': ['이미지에는 3열 표가 보입니다. 열은 flow_id, 연도, 클러스터명으로 구성되어 있고, 왼쪽 열에 F2023_82가 표 전체에 걸쳐 표시되어 있습니다. 연도별로 2023년부터 2025년까지의 기술 전이 흐름이 나열되어 있습니다.\n\n- 2023년: 로봇 조작을 위한 강화 학습 기반 기술\n- 2024년: 심층 강화 학습 기반 로봇 조작 시스템\n- 2025년: 자율형 고숙련 조작 인텔리전스\n\n이 표는 특정 흐름(F2023_82)에 대한 연도별 클러스터명을 정리한 내용입니다.', '다음 이미지의 내용은 연도별 기술 전이 흐름을 정리한 표입니다.\n\n- 표 머리열: flow_id, 연도, 기술 클러스터명\n- 왼쪽 열에는 F2019_77의 흐름 ID가 여러 행에 걸쳐 표시됩니다.\n- 각 행은 2019년부터 2025년까지의 연도에 해당하는 기술 클러스터명을 나타냅니다.\n\n연도별 기술 클러스터명\n- 2019: 비주얼 질문 응답 시스템\n- 2020: 제로샷 이미지 분류 시스템\n- 2021: 제로샷 이미지 분류 기술\n- 2022: 제로샷 이미지 분류 기술\n- 2023: 제로샷 도메인 적응 기술\n- 2024: 제로샷 이미지 분류 기술\n- 2025: 다중모달 AI 영상 시스템\n\n출처는 저자 작성으로 표 하단에 표기되어 있습니다.', '다음 표의 내용을 한국어로 설명합니다.\n\n- 표 구성: flow_id, 연도, 클러스터명 열로 구성된 표. 항목은 F2021_60 흐름을 따라 연도별로 기술 전이 흐름을 보여줍니다.\n- 흐름 식별자: F2021_60\n- 연도별 클러스터명(2021년부터 2025년까지):\n  - 2021년: 사회적 네트워크 동적 군집 탐지 기술\n  - 2022년: 시공간 그래프 예측 기술\n  - 2023년: 도시 교통 흐름 예측 시스템\n  - 2024년: 도시 이동성 예측 시스템\n  - 2025년: 지능형 교통 예측 및 자율주행 시스템\n\n해당 표는 부표 11의 "지능형 교통 예측 및 자율주행 시스템 기술 전이 흐름"에 속하는 다중 에이전트 자율 시스템과 관련된 분산 AI 얼라인먼트 흐름의 일부를 나타냅니다.'], 'id': 73, 'title': 'SPRI_is_213', 'category': 'issue-report', 'tag': ['미래기술', '산업전망', 'AI스타트업', 'AI인재']}
# Indexed: doc_id:499
# {'page': 41, 'image_id': [417, 420, 423], 'image_path': ['/images/SPRI_is_213_cropped_table_417.png', '/images/SPRI_is_213_cropped_table_420.png', '/images/SPRI_is_213_cropped_table_423.png'], 'text_summary': '다음은 제공된 텍스트의 간단한 요약입니다.\n\n- 본 문서는 SPRi 이슈리포트 IS-213의 일부로, 2대 주요 기술군의 기술 전이 흐름을 연도별로 정리한 표를 제시합니다.\n- 부표 9: 자율형 고숙련 조작 인텔리전스 기술 전이 흐름\n  - 연도에 따른 기술 클러스터 변화가 제시됩니다(예: 2023년 “로봇 조작을 위한 강화 학습 기반 기술”, 2024년 “심층 강화 학습 기반 로봇 조작 시스템”, 2025년 “자율형 고숙련 조작 인텔리전스”).\n- 부표 10: 다중모달 AI 영상 시스템 기술군 전이 흐름\n  - 2019년부터 2025년까지의 흐름을 연도별로 정리합니다. 예: 2019년 “비주얼 질문 응답 시스템”에서 시작해 2025년엔 “다중모달 AI 영상 시스템”으로 귀결하는 흐름이 제시됩니다.\n- 부표 11: 지능형 교통 예측 및 자율주행 시스템 기술 전이 흐름\n  - 2021년부터 2025년까지의 흐름이 연도별로 제시됩니다. 예: 2021년 “사회적 네트워크 동적 군집 탐지 기술”에서 시작해 2025년엔 “지능형 교통 예측 및 자율주행 시스템”으로 확장됩니다.\n- 총평: 각 표의 흐름은 특정 연도에 대응하는 기술 클러스터를 따라 기술 전이의 경로를 보여주며, 출처는 저자 작성으로 표기됩니다.\n- 4. 약신호 4: 분산 AI 얼라인먼트 섹션은 관찰 기간 동안 추적된 주요 기술군으로 다중 에이전트 자율 시스템을 언급하고 있으며, 페이지 표기로 보아 문서의 특정 부분(35쪽)에서 다루어집니다.', 'image_summary': ['이미지에는 3열 표가 보입니다. 열은 flow_id, 연도, 클러스터명으로 구성되어 있고, 왼쪽 열에 F2023_82가 표 전체에 걸쳐 표시되어 있습니다. 연도별로 2023년부터 2025년까지의 기술 전이 흐름이 나열되어 있습니다.\n\n- 2023년: 로봇 조작을 위한 강화 학습 기반 기술\n- 2024년: 심층 강화 학습 기반 로봇 조작 시스템\n- 2025년: 자율형 고숙련 조작 인텔리전스\n\n이 표는 특정 흐름(F2023_82)에 대한 연도별 클러스터명을 정리한 내용입니다.', '다음 이미지의 내용은 연도별 기술 전이 흐름을 정리한 표입니다.\n\n- 표 머리열: flow_id, 연도, 기술 클러스터명\n- 왼쪽 열에는 F2019_77의 흐름 ID가 여러 행에 걸쳐 표시됩니다.\n- 각 행은 2019년부터 2025년까지의 연도에 해당하는 기술 클러스터명을 나타냅니다.\n\n연도별 기술 클러스터명\n- 2019: 비주얼 질문 응답 시스템\n- 2020: 제로샷 이미지 분류 시스템\n- 2021: 제로샷 이미지 분류 기술\n- 2022: 제로샷 이미지 분류 기술\n- 2023: 제로샷 도메인 적응 기술\n- 2024: 제로샷 이미지 분류 기술\n- 2025: 다중모달 AI 영상 시스템\n\n출처는 저자 작성으로 표 하단에 표기되어 있습니다.', '다음 표의 내용을 한국어로 설명합니다.\n\n- 표 구성: flow_id, 연도, 클러스터명 열로 구성된 표. 항목은 F2021_60 흐름을 따라 연도별로 기술 전이 흐름을 보여줍니다.\n- 흐름 식별자: F2021_60\n- 연도별 클러스터명(2021년부터 2025년까지):\n  - 2021년: 사회적 네트워크 동적 군집 탐지 기술\n  - 2022년: 시공간 그래프 예측 기술\n  - 2023년: 도시 교통 흐름 예측 시스템\n  - 2024년: 도시 이동성 예측 시스템\n  - 2025년: 지능형 교통 예측 및 자율주행 시스템\n\n해당 표는 부표 11의 "지능형 교통 예측 및 자율주행 시스템 기술 전이 흐름"에 속하는 다중 에이전트 자율 시스템과 관련된 분산 AI 얼라인먼트 흐름의 일부를 나타냅니다.'], 'id': 74, 'title': 'SPRI_is_213', 'category': 'issue-report', 'tag': ['미래기술', '산업전망', 'AI스타트업', 'AI인재']}
# Indexed: doc_id:500
# {'page': 42, 'image_id': [432], 'image_path': ['/images/SPRI_is_213_cropped_table_432.png'], 'text_summary': '다음은 주어진 텍스트의 간단한 요약입니다.\n\n- 이 문서는 SPRi 이슈리포트 IS-213의 일부로, 2026년 디지털 미래기술 전망을 다루며 데이터 속 징후로부터 미래의 실루엣을 제시한다.\n- [부표 12]는 다중 에이전트 자율 시스템을 위한 딥 강화 학습(DRL) 전이 흐름을 연도별로 정리한 표로, 2017년의 DRL 기반 로봇 제어에서 시작해 오프라인 RL, 다중 에이전트 RL 최적화 및 기술화 방향으로 2017–2025년에 걸친 흐름을 보여준다.\n- 약신호 5: 양자 감지(X)에서는 관찰 기간 동안 상위 5대 기술군이 양자 정보 및 지원 기술과 동일하게 나타난다.\n- 약신호 6: 재구성 지능형 표면(RIS)에서는 상위 5대 주요 기술군이 지능형 메타표면 기반 통합 센싱-통신 기술, 동영상 시공간 분석 및 다중모달 이해, 자율형 고숙련 조작 인텔리전스, 다중모달 AI 영상 시스템, 지능형 다중 센서 융합 분석 등으로 요약된다.\n- 출처는 저자 작성이다.', 'image_summary': '다음 그림은 SPRi 이슈리포트의 표(표의 흐름 F2017_31)를 한국어로 설명한 내용입니다. 흐름은 다중 에이전트 자율 시스템을 위한 딥 강화 학습의 연도별 전이 흐름을 보여주고 있으며, 연도별로 각 시기의 클러스터명을 제시하고 있습니다.\n\n주요 내용\n- 표 제목/구성: flow_id, 연도, 클러스터명\n- 왼쪽 열은 F2017_31이라는 흐름 식별자를 하나의 묶음으로 표시\n- 연도별로 2017년부터 2025년까지의 클러스터명 제시\n\n연도별 클러스터명\n- 2017: 심층 강화 학습 기반 로봇 제어 시스템\n- 2018: 다중 에이전트 강화 학습 최적화 시스템\n- 2019: 심층 강화 학습 기반 다중 에이전트 최적화 시스템\n- 2020: 다중 에이전트 최적화 시스템\n- 2021: 오프라인 다중 에이전트 강화 학습 최적화 시스템\n- 2022: 오프라인 강화 학습 기반 로봇 제어 시스템\n- 2023: 다중 에이전트 강화 학습 최적화 시스템\n- 2024: 다중 에이전트 강화 학습 최적화 기술\n- 2025: 다중 에이전트 자율 시스템을 위한 딥 강화 학습\n\n참고: 출처는 저자 작성으로 표 하단에 표시되어 있습니다.', 'id': 75, 'title': 'SPRI_is_213', 'category': 'issue-report', 'tag': ['미래기술', '산업전망', 'AI스타트업', 'AI인재']}
# Indexed: doc_id:501
# {'page': 42, 'image_id': [432], 'image_path': ['/images/SPRI_is_213_cropped_table_432.png'], 'text_summary': '다음은 주어진 텍스트의 간단한 요약입니다.\n\n- 이 문서는 SPRi 이슈리포트 IS-213의 일부로, 2026년 디지털 미래기술 전망을 다루며 데이터 속 징후로부터 미래의 실루엣을 제시한다.\n- [부표 12]는 다중 에이전트 자율 시스템을 위한 딥 강화 학습(DRL) 전이 흐름을 연도별로 정리한 표로, 2017년의 DRL 기반 로봇 제어에서 시작해 오프라인 RL, 다중 에이전트 RL 최적화 및 기술화 방향으로 2017–2025년에 걸친 흐름을 보여준다.\n- 약신호 5: 양자 감지(X)에서는 관찰 기간 동안 상위 5대 기술군이 양자 정보 및 지원 기술과 동일하게 나타난다.\n- 약신호 6: 재구성 지능형 표면(RIS)에서는 상위 5대 주요 기술군이 지능형 메타표면 기반 통합 센싱-통신 기술, 동영상 시공간 분석 및 다중모달 이해, 자율형 고숙련 조작 인텔리전스, 다중모달 AI 영상 시스템, 지능형 다중 센서 융합 분석 등으로 요약된다.\n- 출처는 저자 작성이다.', 'image_summary': '다음 그림은 SPRi 이슈리포트의 표(표의 흐름 F2017_31)를 한국어로 설명한 내용입니다. 흐름은 다중 에이전트 자율 시스템을 위한 딥 강화 학습의 연도별 전이 흐름을 보여주고 있으며, 연도별로 각 시기의 클러스터명을 제시하고 있습니다.\n\n주요 내용\n- 표 제목/구성: flow_id, 연도, 클러스터명\n- 왼쪽 열은 F2017_31이라는 흐름 식별자를 하나의 묶음으로 표시\n- 연도별로 2017년부터 2025년까지의 클러스터명 제시\n\n연도별 클러스터명\n- 2017: 심층 강화 학습 기반 로봇 제어 시스템\n- 2018: 다중 에이전트 강화 학습 최적화 시스템\n- 2019: 심층 강화 학습 기반 다중 에이전트 최적화 시스템\n- 2020: 다중 에이전트 최적화 시스템\n- 2021: 오프라인 다중 에이전트 강화 학습 최적화 시스템\n- 2022: 오프라인 강화 학습 기반 로봇 제어 시스템\n- 2023: 다중 에이전트 강화 학습 최적화 시스템\n- 2024: 다중 에이전트 강화 학습 최적화 기술\n- 2025: 다중 에이전트 자율 시스템을 위한 딥 강화 학습\n\n참고: 출처는 저자 작성으로 표 하단에 표시되어 있습니다.', 'id': 76, 'title': 'SPRI_is_213', 'category': 'issue-report', 'tag': ['미래기술', '산업전망', 'AI스타트업', 'AI인재']}
# Indexed: doc_id:502
# {'page': 43, 'image_id': [442, 445], 'image_path': ['/images/SPRI_is_213_cropped_table_442.png', '/images/SPRI_is_213_cropped_table_445.png'], 'text_summary': '다음은 텍스트의 핵심 내용을 한국어로 요약한 것 입니다.\n\n- 문서 형식\n  - SPRi 이슈리포트 IS-213의 부표 13과 부표 14에 수록된 두 개의 기술 전이 흐름 표가 제시되어 있습니다.\n  - 각 표는 flow_id, 연도, 클러스터명(기술 흐름의 주제)을 나열하고 있습니다.\n  - 출처는 저자 작성입니다.\n\n- 부표 13: 지능형 메타표면 기반 통합 센싱-통신 기술 전이 흐름\n  - 2007년부터 2025년까지 무선 네트워크 최적화와 관련된 기술 흐름이 연도별로 제시되어 있습니다.\n  - 주요 흐름 요지\n    - 2007년: 다중 사용자 무선 통신 시스템의 간섭 최적화 기술\n    - 2008–2014년대: 무선 센서 네트워크의 동적 자원 관리, 트래픽 관리, 자원 할당 최적화 기술 등 네트워크 최적화의 확장\n    - 2015–2019년대: 무선 네트워크 자원 할당의 최적화, 에너지 효율적 자원 할당, 대규모 MIMO 채널 추정 및 빔포밍 최적화 등\n    - 2020년대 초반: 대규모 MIMO 기반의 채널 추정, 신호 복조 및 간섭 최적화 기술\n    - 2021–2024년: 대규모 MIMO 기반 지능형 무선 통신 시스템 설계·최적화 및 채널 추정/간섭 최적화의 진전\n    - 2025년: 지능형 메타표면 기반 통합 센싱-통신 기술로 마무리\n  - 요지: 무선 네트워크의 최적화에서 시작해 대규모 MIMO 및 채널 추정/빔포밍 중심으로 발전해 나가며, 마지막에 지능형 메타표면 기반의 통합 센싱-통신 기술로 전이됩니다.\n\n- 부표 14: 동영상 시공간 분석 및 다중모달 이해 기술 전이 흐름\n  - 2023년부터 2025년까지의 영상 분석/인공지능 기반 기술 흐름을 제시합니다.\n  - 주요 흐름 요지\n    - 2023년: 비디오 품질 평가를 위한 변환기(트랜스포머) 기반 압축 시스템\n    - 2024년: 다중 객체 행동 인식 및 추적 시스템\n    - 2025년: 동영상 시공간 분석 및 다중모달 이해 기술\n  - 요지: 영상 분석 및 다중모달 이해 분야에서 트랜스포머 기반 기법과 객체 인식/추적에서 시공간 분석 및 다중모달 이해로의 진전이 이루어지는 흐름을 제시합니다.\n\n전체적으로 두 부표 모두 특정 기술 분야의 연도별 전이 흐름을 표로 정리하여, 각각의 시점에서 주목되는 연구 주제와 발전 방향을 제시하고 있습니다.', 'image_summary': ['이미지는 flow_id가 F2007_62인 연도별 클러스터명을 나열한 표입니다. 표의 구성은 다음과 같습니다.\n\n- 열: flow_id, 연도, 클러스터명\n- 왼쪽 열에 흐름 식별자 F2007_62가 보이고, 중앙 열에는 연도(2007~2025)가, 오른쪽 열에는 각 해에 해당하는 클러스터명이 한글로 적혀 있습니다.\n- 주요 내용은 무선 통신 시스템의 최적화와 자원 관리, 무선 네트워크의 자원 할당 및 관리, 대규모 MIMO 기술의 채널 추정/빔포밍, 에너지 효율, 그리고 지능형 메타표면 기반 센싱-통신 기술 등으로 연도별로 변하고 있다는 점입니다.\n  - 예: 2007년 "다중 사용자 무선 통신 시스템의 간섭 최적화 기술" → 2008년 "무선 센서 네트워크를 위한 동적 자원 관리 시스템" → … → 2025년 "지능형 메타표면 기반 통합 센싱-통신 기술".\n- 표 하단에 출처로 "저자 작성"과 같은 주석이 포함되어 있습니다.', '이미지는 흐름 식별 표(flow_id)과 연도, 클러스터명을 나열한 표입니다. 하나의 행 F2023_98이 왼쪽에 있고, 연도 열에는 2023, 2024, 2025가 각각 표시되어 있습니다. 클러스터명 열에는 각 연도에 해당하는 세 가지 클러스터 내용이 적혀 있습니다:\n- 2023년: 비디오 품질 평가를 위한 변환기 기반 압축 시스템\n- 2024년: 다중 객체 행동 인식 및 추적 시스템\n- 2025년: 동영상 시공간 분석 및 다중모달 이해 기술'], 'id': 77, 'title': 'SPRI_is_213', 'category': 'issue-report', 'tag': ['미래기술', '산업전망', 'AI스타트업', 'AI인재']}
# Indexed: doc_id:503
# {'page': 43, 'image_id': [442, 445], 'image_path': ['/images/SPRI_is_213_cropped_table_442.png', '/images/SPRI_is_213_cropped_table_445.png'], 'text_summary': '다음은 텍스트의 핵심 내용을 한국어로 요약한 것 입니다.\n\n- 문서 형식\n  - SPRi 이슈리포트 IS-213의 부표 13과 부표 14에 수록된 두 개의 기술 전이 흐름 표가 제시되어 있습니다.\n  - 각 표는 flow_id, 연도, 클러스터명(기술 흐름의 주제)을 나열하고 있습니다.\n  - 출처는 저자 작성입니다.\n\n- 부표 13: 지능형 메타표면 기반 통합 센싱-통신 기술 전이 흐름\n  - 2007년부터 2025년까지 무선 네트워크 최적화와 관련된 기술 흐름이 연도별로 제시되어 있습니다.\n  - 주요 흐름 요지\n    - 2007년: 다중 사용자 무선 통신 시스템의 간섭 최적화 기술\n    - 2008–2014년대: 무선 센서 네트워크의 동적 자원 관리, 트래픽 관리, 자원 할당 최적화 기술 등 네트워크 최적화의 확장\n    - 2015–2019년대: 무선 네트워크 자원 할당의 최적화, 에너지 효율적 자원 할당, 대규모 MIMO 채널 추정 및 빔포밍 최적화 등\n    - 2020년대 초반: 대규모 MIMO 기반의 채널 추정, 신호 복조 및 간섭 최적화 기술\n    - 2021–2024년: 대규모 MIMO 기반 지능형 무선 통신 시스템 설계·최적화 및 채널 추정/간섭 최적화의 진전\n    - 2025년: 지능형 메타표면 기반 통합 센싱-통신 기술로 마무리\n  - 요지: 무선 네트워크의 최적화에서 시작해 대규모 MIMO 및 채널 추정/빔포밍 중심으로 발전해 나가며, 마지막에 지능형 메타표면 기반의 통합 센싱-통신 기술로 전이됩니다.\n\n- 부표 14: 동영상 시공간 분석 및 다중모달 이해 기술 전이 흐름\n  - 2023년부터 2025년까지의 영상 분석/인공지능 기반 기술 흐름을 제시합니다.\n  - 주요 흐름 요지\n    - 2023년: 비디오 품질 평가를 위한 변환기(트랜스포머) 기반 압축 시스템\n    - 2024년: 다중 객체 행동 인식 및 추적 시스템\n    - 2025년: 동영상 시공간 분석 및 다중모달 이해 기술\n  - 요지: 영상 분석 및 다중모달 이해 분야에서 트랜스포머 기반 기법과 객체 인식/추적에서 시공간 분석 및 다중모달 이해로의 진전이 이루어지는 흐름을 제시합니다.\n\n전체적으로 두 부표 모두 특정 기술 분야의 연도별 전이 흐름을 표로 정리하여, 각각의 시점에서 주목되는 연구 주제와 발전 방향을 제시하고 있습니다.', 'image_summary': ['이미지는 flow_id가 F2007_62인 연도별 클러스터명을 나열한 표입니다. 표의 구성은 다음과 같습니다.\n\n- 열: flow_id, 연도, 클러스터명\n- 왼쪽 열에 흐름 식별자 F2007_62가 보이고, 중앙 열에는 연도(2007~2025)가, 오른쪽 열에는 각 해에 해당하는 클러스터명이 한글로 적혀 있습니다.\n- 주요 내용은 무선 통신 시스템의 최적화와 자원 관리, 무선 네트워크의 자원 할당 및 관리, 대규모 MIMO 기술의 채널 추정/빔포밍, 에너지 효율, 그리고 지능형 메타표면 기반 센싱-통신 기술 등으로 연도별로 변하고 있다는 점입니다.\n  - 예: 2007년 "다중 사용자 무선 통신 시스템의 간섭 최적화 기술" → 2008년 "무선 센서 네트워크를 위한 동적 자원 관리 시스템" → … → 2025년 "지능형 메타표면 기반 통합 센싱-통신 기술".\n- 표 하단에 출처로 "저자 작성"과 같은 주석이 포함되어 있습니다.', '이미지는 흐름 식별 표(flow_id)과 연도, 클러스터명을 나열한 표입니다. 하나의 행 F2023_98이 왼쪽에 있고, 연도 열에는 2023, 2024, 2025가 각각 표시되어 있습니다. 클러스터명 열에는 각 연도에 해당하는 세 가지 클러스터 내용이 적혀 있습니다:\n- 2023년: 비디오 품질 평가를 위한 변환기 기반 압축 시스템\n- 2024년: 다중 객체 행동 인식 및 추적 시스템\n- 2025년: 동영상 시공간 분석 및 다중모달 이해 기술'], 'id': 78, 'title': 'SPRI_is_213', 'category': 'issue-report', 'tag': ['미래기술', '산업전망', 'AI스타트업', 'AI인재']}
# Indexed: doc_id:504
# {'page': 44, 'image_id': [451], 'image_path': ['/images/SPRI_is_213_cropped_table_451.png'], 'text_summary': [], 'image_summary': '다음은 이미지에 담긴 내용의 한국어 설명입니다.\n\n- 이미지 제목/맥락: SPRi 이슈리포트 IS-213의 부표 15에 해당하는 "지능형 다중 센서 융합 분석 기술 전이 흐름" 표.\n- 형태: 세 열로 구성된 표( flow_id, 연도, 클러스터명 )가 담긴 표 형식의 데이터. 표 상단은 파란색 헤더로 각 열 제목이 적혀 있음.\n- 왼쪽 열(flow_id): 주로 F2016_34로 시작하며, 2016년에 해당하는 흐름을 나타냄.\n- 가운데 열(연도): 2016년부터 2025년까지 연도들이 연속으로 기재되어 있음.\n- 오른쪽 열(클러스터명): 각 연도에 대응하는 클러스터명(연구 주제)을 나열. 연도별 주제는 다음과 같음.\n  - 2016: 다중 모달 인간 동작 인식 시스템\n  - 2017: 인간 행동 인식 및 자세 추정 시스템\n  - 2018: 인간 활동 인식을 위한 심층 신경망 최적화 기술\n  - 2019: 인간 행동 인식을 위한 시공간 네트워크 기술\n  - 2020: 다중 모달 인간 행동 인식 시스템\n  - 2021: 인간 동작 인식 시스템\n  - 2022: 다중 모달 영상 행동 인식 시스템\n  - 2023: 인간 행동 인식 시스템\n  - 2024: 인간 활동 인식 시스템\n  - 2025: 지능형 다중 센서 융합 분석\n- 하단 메모: 출처는 "저자 작성"으로 표기된 주석이 따로 있음.\n- 특징: 연도에 따라 인간 행동/동작 인식과 다중 센서 융합 분석 기술의 발전 흐름을 연도별로 정리한 진척 맥락을 보여주는 표임.', 'id': 79, 'title': 'SPRI_is_213', 'category': 'issue-report', 'tag': ['미래기술', '산업전망', 'AI스타트업', 'AI인재']}
# Indexed: doc_id:505
# {'page': 45, 'image_id': [], 'image_path': [], 'text_summary': [], 'image_summary': [], 'id': 80, 'title': 'SPRI_is_213', 'category': 'issue-report', 'tag': ['미래기술', '산업전망', 'AI스타트업', 'AI인재']}
# Indexed: doc_id:506
# {'page': 46, 'image_id': [], 'image_path': [], 'text_summary': [], 'image_summary': [], 'id': 81, 'title': 'SPRI_is_213', 'category': 'issue-report', 'tag': ['미래기술', '산업전망', 'AI스타트업', 'AI인재']}
# Indexed: doc_id:507

# %%
# Hybrid search: Combine vector search with text search
def hybrid_search(query_text, top_k=5):
    query_vector = model.embed_query(query_text)
    
    common_filters = {
        "bool": {
            "should": [ # or
                {"term": {"metadata.tag": 'AI인재'}},
                {"term": {"metadata.tag": 'AI스타트업'}},
            ],
            "must_not": [
                {"term": {"metadata.tag": 'AI인덱스'}},
            ]
        }
    }

    # Combine KNN with text search
    hybrid_query = {
        "query": {
            "bool": {
                "must": [
                    {
                        "match": {
                            "text": query_text
                        }
                    }
                ],
                "filter": common_filters  # Use same filter
            }
        },
        "knn": {
            "field": "vector",
            "query_vector": query_vector,
            "k": top_k,
            "num_candidates": 100,
            "filter": common_filters  # Reuse same filter
        },
        "_source": ["text", "metadata"]
    }
    
    response = es.search(index=index_name, body=hybrid_query)
    return response

print(f"\n\n{'='*60}")
print("HYBRID SEARCH (Vector + Text)")
print('='*60)
print("Query: AI 트렌드")

results = hybrid_search("AI 트렌드", top_k=5)
# Out:
# ============================================================
# HYBRID SEARCH (Vector + Text)
# ============================================================
# Query: AI 트렌드

# %%
from langchain_core.documents import Document
docs = []
for r in results['hits']['hits'][:5]:
    doc = Document(page_content=r['_source']['text'], metadata=r['_source']['metadata'])
    docs.append(doc)
