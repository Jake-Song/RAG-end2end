# %%
import os
import sys
from pathlib import Path

# Add the project root to the Python path
project_root = Path().resolve().parent
sys.path.insert(0, str(project_root))

from dotenv import load_dotenv
load_dotenv()
from langchain_upstage import UpstageEmbeddings
embeddings = UpstageEmbeddings(model="embedding-passage")

DB_URI = os.environ["POSTGRES_URI"]     

from langchain_postgres import PGVector
from langchain_core.documents import Document
vector_store = PGVector(
    embeddings=embeddings,
    collection_name="SPRI_ALL",
    connection=DB_URI
)

# %%
import pickle
papers = []
for path in sorted(Path(project_root).joinpath("outputs").glob("SPRI_*_split_documents.pkl")):
    
    with open(path, "rb") as f:
        split_documents = pickle.load(f)
        for doc in split_documents:
            name = path.stem.replace("_output_split_documents", "")
            doc.metadata["title"] = name
           
            if name in ["SPRI_2022", "SPRI_2023", "SPRI_2025"]:
                doc.metadata["category"] = "AI-index"
                if name == "SPRI_2022":
                    doc.metadata["tag"] = ["AI인덱스", "AI트렌드", "AI윤리", "AI인재"]
                elif name == "SPRI_2023":
                    doc.metadata["tag"] = ["AI인덱스", "AI트렌드", "AI규제", "AI인재"]
                elif name == "SPRI_2025":
                    doc.metadata["tag"] = ["AI인덱스", "AI트렌드", "AI스타트업", "정부정책"]
            elif "SPRI_is" in name:
                doc.metadata["category"] = "issue-report"
                if name == "SPRI_is_211":
                    doc.metadata["tag"] = ["AI스타트업", "기술사업화", "기업가정신", "AI인재"]
                elif name == "SPRI_is_212":
                    doc.metadata["tag"] = ["SW안전", "기능안전", "오토파일럿"]
                elif name == "SPRI_is_213":
                    doc.metadata["tag"] = ["미래기술", "산업전망", "AI스타트업", "AI인재"]
            elif "SPRI_c" in name:
                doc.metadata["category"] = "column"
                if name == "SPRI_c_1":
                    doc.metadata["tag"] = ["Govtech", "정부혁신", "디지털정부", "제도주의"]
                elif name == "SPRI_c_2":
                    doc.metadata["tag"] = ["개방형혁신", "SaaS", "AI인재"]
                elif name == "SPRI_c_3":
                    doc.metadata["tag"] = ["산업전망", "기업가정신", "AI윤리", "AI인재"]
                
                    
    papers.append(split_documents)

# %%
for paper in papers:
    vector_store.add_documents(paper)

# %%
retriever = vector_store.as_retriever(search_kwargs={"k": 10, "filter": 
{"$and": [
            {"tag": {"$eq": ["AI인재"]}},
            {"tag": {"$ne": ["AI트렌드"]}}
        ]}
})

# %%
retriever.invoke("AI 인덱스")
# Out:
# [Document(id='250c30ca-09f7-4d71-b8f3-cf9322068842', metadata={'id': 84, 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재'], 'page': 42, 'title': 'SPRI_2022', 'category': 'AI-index', 'image_id': [], 'image_path': [], 'text_summary': [], 'image_summary': []}, page_content='SPRi 이슈리포트 IS-139\n\n\n  \nAI Index 2022의 주요 내용 및 시사점\n\n참고문헌\n====\n\n국외문헌\n====\n\n  \n\n§ Daniel Zhang, Nestor Maslej, Erik Brynjolfsson, John Etchemendy, Terah  \nLyons, James Manyika, Helen Ngo, Juan Carlos Niebles, Michael Sellitto, Ellie  \nSakhaee, Yoav Shoham, Jack Clark, and Raymond Perrault, “The AI Index  \n2022 Annual Report,” AI Index Steering Committee, Stanford Institute for  \nHuman-Centered AI, Stanford University, March 2022\n\n37'),
#  Document(id='b80d26ee-b3be-40ed-b722-8d526128c926', metadata={'id': 9, 'tag': ['AI인덱스', 'AI트렌드', 'AI규제', 'AI인재'], 'page': 7, 'title': 'SPRI_2023', 'category': 'AI-index', 'image_id': [41], 'image_path': ['/images/SPRI_2023_cropped_table_41.png'], 'text_summary': '다음은 제공된 텍스트의 요약입니다.\n\n- 주제: SPRi 이슈리포트 IS-159의 핵심 내용은 AI Index 2023의 주요 내용과 시사점을 정리한 것.\n- AI Index의 기원 및 목적: 스탠퍼드 대학 HAI가 2017년부터 글로벌 AI 연구개발, 기술 수준, 경제/고용, 정책 동향 등 자료를 분석해 국가 간 비교가 가능한 지수로 제시하는 연례보고서.\n- 특징: 경제와 교육 분야를 구분하고, 다양성 및 여론조사 결과를 추가로 반영.\n- 분야별 주요 내용:\n  - 연구분야: 미국과 중국이 주도하며, 중국이 출판량·인용에서 미국을 추월하는 추세. 양국 간 협력 연구가 증가하고, 대학은 활발하지만 새로운 모델 개발은 산업이 앞섬.\n  - 기술성능: 벤치마크에서 성능 정점에 도달하는 등 지속적 향상. 고성능·저비용 하드웨어로 연구 장벽이 완화.\n  - AI윤리: 윤리 이슈 사례 증가. 오남용 방지, 공정성, 투명성 관련 연구와 지표도 증가.\n  - AI투자: 글로벌 경기 침체 영향으로 AI 투자 감소 국면 진입(2013년 이후 처음). 다만 AI 기업에 대한 투자와 AI 직군 수요는 여전히 높은 편.\n  - AI교육: 고등교육 중심에서 중등 교육으로 확산되는 흐름이 뚜렷하고, 다양한 국가로 확산 중.\n  - 정책: 2019년 정점 이후 감소하지만, AI 확산과 함께 소송 증가 및 입법이 크게 늘어남.\n  - 다양성: 성별·인종 등 다양성 격차는 여전하나 점진적으로 완화 중.\n  - 여론: 개인별·국가별 차이가 있으나 전반적으로 긍정적 의견이 우세.\n- 용어 해설: 1) Stanford HAI는 스탠퍼드 대학의 인간중심 인공지능 연구소를 뜻함.', 'image_summary': '이미지 내용 요약\n\n- 표 구성: 분야(왼쪽 열)와 내용(오른쪽 열)으로 이루어진 두 열의 표가 보이며, 8개 분야에 대해 핵심 내용을 요약하고 있습니다.\n- 분야 목록: 연구분야, 기술성능, AI윤리, AI투자, AI교육, 정책, 다양성, 여론\n\n각 분야의 주 내용\n- 연구분야: 미국과 중국이 주도하며 중국이 미국의 출판량·인용수를 추월하고 있는 가운데 양국 간 협력 연구가 증가하고, 대학이 가장 활발한 연구주체이나 새로운 모델 개발은 산업이 앞서고 있음.\n- 기술성능: AI 성능 향상은 여러 벤치마크에서 정점을 찍고 지속적으로 개선되며, 고성능·저비용의 하드웨어로 연구 장벽이 낮아지는 추세.\n- AI윤리: AI 윤리 이슈 관련 사례 증가, AI의 오남용 방지, 공정성·투명성 관련 연구와 지표가 증가하고 있음.\n- AI투자: 글로벌 경기 침체로 AI 분야의 투자 세가 처음으로 감소하는 흐름으로 전환되었으나, AI 관련 기업에 대한 투자와 전 세계 AI 직군의 인력 수요는 여전히 높은 편.\n- AI교육: 기존의 고등교육 중심에서 초중등 교육으로 AI 교육이 점차 보편화되고 다양한 국가로 확산 중.\n- 정책: 2019년을 정점으로 AI 국가 전략 발표는 감소하는 추세이나, AI 확산과 함께 AI 관련 소송과 각국의 AI 관련 입법이 크게 증가하고 있음.\n- 다양성: AI 전문 연구 인력의 성별·인종 등 다양성 측면의 격차는 여전하나 점차 완화되고 있음.\n- 여론: AI 인식은 개인·국가별로 차이가 있지만 대체로 긍정적인 의견이 부정적보다 우세한 편.'}, page_content='SPRi 이슈리포트 IS-159\n\n\n  \nAI Index 2023의 주요 내용 및 시사점\n\nI. AI Index 2023 주요내용\n=====================\n\n1.1 보고서 개요 및 특징\n===============\n\n□ AI Index는 미국 스탠퍼드大 HAI1)에서 2017년부터 글로벌 인공지능(AI)  \n관련 연구개발, 기술 수준, 경제, 고용, 정책 동향 관련 자료와 데이터를 분석 ․  \n종합한 연례보고서\n\n◦ 학술단체, 민간, 비영리기관 등의 발행 자료들을 정량화해 국가 간 비교가  \n가능한 지수(index)로 표시하여 AI 관련 연구자, 정책입안자, 및  \n이해관계자들에게 다양한 정보 제공\n\n◦ 이번 보고서의 특징은, 경제와 교육 분야를 나누고 다양성과 여론조사 결과  \n등이 추가\n\n□ 주요 내용 요약\n==========\n\n![](/images/SPRI_2023_cropped_table_41.png)'),
#  Document(id='894acb87-090d-4701-b258-55c86466e9b6', metadata={'id': 51, 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재'], 'page': 29, 'title': 'SPRI_2022', 'category': 'AI-index', 'image_id': [371, 373], 'image_path': ['/images/SPRI_2022_cropped_chart_371.png', '/images/SPRI_2022_cropped_chart_373.png'], 'text_summary': '다음은 주어진 텍스트의 핵심 내용을 요약한 것입니다.\n\n- 문서 개요: SPRi 이슈리포트 IS-139는 AI Index 2022의 주요 내용과 시사점을 정리한 자료로, AI 투자 흐름과 기업의 AI 활용 현황을 다루고 있습니다(출처: Stanford HAI, AI Index Report 2022).\n\n- 2021년 AI 스타트업 투자 현황: 각국의 AI 스타트업 투자 규모를 국가별로 제시하고 있습니다(자료 그림/표 포함). 자세한 수치는 표 형식으로 제시되나 텍스트에서 표가 왜곡되어 있어 구체 수치는 생략합니다.\n\n- 3. 기업 AI 활용(Corporate Activity)\n  - 글로벌 기업의 AI 활용률은 2021년에 56%로, 2020년 대비 6퍼센트포인트 증가.\n  - 조사 대상: 맥킨지의 전 세계 경영자 1,843명 대상 설문.\n  - 지역별 최신 수치: 인도 65%, 아시아태평양 선진국 64%, 신흥국 57%, 북미 55%, 유럽 51%, 라틴아메리카 47%.\n  - 산업·기능별 활용 트렌드: 하이테크·통신산업의 제품/서비스 개발에서 AI 활용률 약 45%로 높음. 금융서비스의 서비스 운영(약 40%)과 리스크 관리(약 32%), 하이테크·통신의 서비스 운영(약 34%)도 높음.\n  - 기술별 활용: 하이테크·통신에서 자연어 텍스트 이해 기술 활용률이 약 34%로 가장 높음.\n  - 추가 활용 사례: 금융서비스업과 자동차 제조(조립) 분야에서 RPA(로봇 프로세스 자동화) 활용률 약 33%, 금융서비스업의 자연어 텍스트 이해 기술 약 32%.\n  - 시사점(위협/리스크): AI 도입에 따라 사이버 보안 등 다양한 위험이 발생할 수 있다는 점이 제시됩니다.\n\n요약하면, 2021년 AI 투자 현황과 글로벌 기업의 AI 채택이 확대되고 있으며, 지역·산업·기술별로 차이가 존재한다는 점과, AI 도입에 따른 사이버 보안 등 위험 관리가 중요한 시사점으로 강조됩니다.', 'image_summary': ['이 이미지는 AI Index 2022의 그림 2-4-1에 해당하는, 2021년 국가별 AI 스타트업 투자 현황을 나타낸 수평 막대그래프입니다. 각 바는 해당 국가의 글로벌 AI 스타트업 투자 비중(%)을 보여줍니다. 주요 내용은 다음과 같습니다.\n\n- 미국: 약 52.85%로 가장 큰 비중\n- 중국: 약 17.21%\n- 영국: 약 4.65%\n- 이스라엘: 약 2.41%\n- 독일: 약 1.98%\n- 캐나다: 약 1.87%\n- 프랑스: 약 1.55%\n- 인도: 약 1.35%\n- 호주: 약 1.25%\n- 대한민국: 약 1.10%\n- 싱가포르: 약 0.93%\n- 스위스: 약 0.89%\n- UAE: 약 0.82%\n- 홍콩: 약 0.63%\n- 포르투갈: 약 0.52%', '다음 이미지는 국가별 신규 투자된 AI 스타트업 수를 나타내는 가로 막대 그래프입니다. 그림의 제목은 (b) 신규 투자 AI 스타트업(개)이며, 축은 0부터 300까지의 건수 단위로 되어 있습니다. 각 막대의 길이가 해당 국가의 투자 건수를 보여줍니다.\n\n주요 내용(대략 값):\n- 미국: 약 299건\n- 중국: 약 119건\n- 영국: 약 19건\n- 이스라엘: 약 28건\n- 프랑스: 약 27건\n- 독일: 약 25건\n- 인도: 약 23건\n- 캐나다: 약 22건\n- 대만: 약 19건\n- 네덜란드: 약 16건\n- 호주: 약 12건\n- 일본: 약 12건\n- 스위스: 약 12건\n- 싱가포르: 약 10건\n- 헝가리: 약 10건\n\n전체적으로 미국이 가장 많고, 중국이 그다음으로 뒤를 잇는 반면 나머지 국가는 10~28건대의 비교적 작은 규모로 분포하는 것을 알 수 있습니다.']}, page_content='SPRi 이슈리포트 IS-139\n\n\n  \nAI Index 2022의 주요 내용 및 시사점\n\n![](/images/SPRI_2022_cropped_chart_371.png)\n\nChart Type: bar\n\n|  | 미국 | 중국 | 영국 | 익스타그램 | 톡 | 캐나다 | 프랑스 | 인도 | 호주 | 대한민국 | 싱가포르 | 스꽤인 | UAE | 홍콩 | 프로모두 |\n| --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |\n| item\\_01 | 52.86 | 17.21 | 4.65 | 2.41 | 1.98 | 1.87 | 1.55 | 1.35 | 1.25 | 1.1 | 0.93 | 0.89 | 0.82 | 0.63 | 0.52 |\n\n  \n\n(a) 투자 금액 (십억 달러)\n\n  \n![](/images/SPRI_2022_cropped_chart_373.png)\n\nChart Type: bar\n\n|  | 미국 | 중국 | 영국 | 히어 | 프랑스 | 테일 | 었다 | 케이 | 대한민국 | 네은드 | 전주 | 일본 | 스위스 | 싱가포르 |\n| --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |\n| item\\_01 | 99TWh | 119TWh | 49TWh | 28TWh | 27TWh | 25TWh | 23TWh | 22TWh | 19TWh | 16TWh | 12TWh | 12TWh | 12TWh | 10TWh |\n\n  \n\n(b) 신규 투자 AI 스타트업 (개)\n\n  \n\n※자료: Stanford HAI, AI Index Report 2022 (재편집)\n\n  \n\n[그림 2-4-1] 국가별 2021년 AI 스타트업 투자현황 (AI Index 2022)\n================================================='),
#  Document(id='e3b57264-5965-405f-ab8b-a344bd0e7e01', metadata={'id': 7, 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재'], 'page': 6, 'title': 'SPRI_2022', 'category': 'AI-index', 'image_id': [], 'image_path': [], 'text_summary': [], 'image_summary': []}, page_content='SPRi 이슈리포트 IS-139\n\n\n  \nAI Index 2022의 주요 내용 및 시사점\n\n1. AI Index 2022 개요\n===================\n\n1. 보고서 개요 및 특징\n==============\n\n□ AI Index는 미국 스탠퍼드大 HAI1)에서 2017년부터 글로벌 인공지능(AI)  \n관련 연구개발, 기술 수준, 경제, 고용, 정책 동향 관련 자료와 데이터를 분석 ․  \n종합한 연례보고서\n\n◦ 학술단체, 민간, 비영리기관 등의 발행 자료들을 정량화해 국가 간 비교가  \n가능한 지수(index)로 표시하여 AI 관련 연구자, 정책입안자, 및  \n이해관계자들에게 다양한 정보 제공\n\n□ 이번 보고서의 특징은, AI 기술 및 AI 신뢰성 검증을 위한 벤치마크,  \n25개국에서 수집한 입법 동향 등이 추가\n\n◦ 특히, 윤리적 인공지능, 신뢰할 만한 인공지능 기술 검증을 위한 여러  \n벤치마크 및 기술적 평가 지표를 활용한 연구 동향을 심층 분석\n\n2. 주요 내용 요약\n===========\n\n□ AI 분야의 민간투자는 ’21년 935억 달러로 ’20년 대비 두 배 성장\n\n□ 연구 분야에서는 미·중이 주도하고 있는 가운데 양국 간 협력 연구도 증가\n\n□ 기술 측면에서 언어모델의 성능이 향상되었으나 편향성 문제도 동시에 증가\n\n□ 전반적으로 AI 윤리 이슈가 부각되어 산업계에서도 AI의 공정성, 투명성 관련  \n연구 증가\n\n□ AI 기술이 점차 고성능·저비용화되어 연구 장벽이 완화되는 추세\n\n□ AI에 대한 입법 활동은 세계적으로 활발히 진행되고 있으나 법제화는 미진\n\n1) Stanford HAI(Stanford Institute for Human Centered Artificial Intelligence), 스탠포드 대학의 인간중심 인공지능  \n연구소\n\n1'),
#  Document(id='fc0a9c91-3106-4ae6-a450-7412e143973e', metadata={'id': 46, 'tag': ['AI인덱스', 'AI트렌드', 'AI규제', 'AI인재'], 'page': 27, 'title': 'SPRI_2023', 'category': 'AI-index', 'image_id': [322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 335, 336, 337, 338, 339], 'image_path': ['/images/SPRI_2023_cropped_figure_322.png', '/images/SPRI_2023_cropped_figure_323.png', '/images/SPRI_2023_cropped_figure_324.png', '/images/SPRI_2023_cropped_figure_325.png', '/images/SPRI_2023_cropped_figure_326.png', '/images/SPRI_2023_cropped_figure_327.png', '/images/SPRI_2023_cropped_figure_328.png', '/images/SPRI_2023_cropped_figure_329.png', '/images/SPRI_2023_cropped_figure_330.png', '/images/SPRI_2023_cropped_figure_331.png', '/images/SPRI_2023_cropped_figure_332.png', '/images/SPRI_2023_cropped_figure_333.png', '/images/SPRI_2023_cropped_figure_335.png', '/images/SPRI_2023_cropped_figure_336.png', '/images/SPRI_2023_cropped_figure_337.png', '/images/SPRI_2023_cropped_figure_338.png', '/images/SPRI_2023_cropped_figure_339.png'], 'text_summary': [], 'image_summary': ['상반신이 보이는 남성 또는 남성형 인물이 검은색 정장을 입고 흰 셔츠에 넥타이를 매고 있다. 팔을 가슴 앞에서 교차시키는 자세이며, 얼굴은 보이지 않는다. 배경은 단순한 색상으로 보인다. 라펠에 작은 배지나 핀 같은 장식이 보일 수 있다.', '사진 속 인물은 회색 계열 정장을 입고 흰 셔츠에 어두운 색 넥타이를 매고 있습니다. 팔을 교차시킨 자세로 카메라를 바라보며 살짝 미소 짓는 표정입니다. 배경은 단색의 중립적인 톤으로 보이고, 머리는 짧고 깔끔하게 정리되어 있습니다. 비즈니스 프로필 사진처럼 보이는 모습입니다.', '이미지 내용 설명: 흰색 상의를 입은 한 사람이 큰 기둥이 보이는 건물 앞의 야외 공간에 서 있다. 정면을 바라보며 두 팔을 옆으로 늘어뜨리고 있고, 배경에 여러 개의 커다란 기둥이 보인다. 바닥은 회색빛의 타일이나 대리석처럼 보인다.', '사진은 성인 남성의 상반신 머리샷으로, 회색 계열 재킷에 흰 셔츠, 붉은 넥타이를 매고 있다. 그는 미소를 지으며 카메라를 바라보고 있고, 짧은 머리와 약간의 수염이 보인다. 배경은 중립적인 회색 톤으로 단순하다. 신원은 식별할 수 없다.', '다음과 같은 내용의 초상 사진입니다(한국어 설명):\n\n- 상반신이 보이는 남성의 초상 사진.\n- 중년으로 보이는 남성이 파란색 재킷을 입고 있으며, 안에 밝은 색 셔츠를 입고 있음.\n- 안경을 착용하고 있음.\n- 팔을 가슴 앞에서 교차한 자세.\n- 표정은 중립적이고 미소는 거의 없음.\n- 배경은 따뜻한 갈색 톤의 목재 패널처럼 보이는 벽면의 환경에서 촬영된 것처럼 보임.\n- 조명은 얼굴이 잘 보이도록 부드럽게 비춘 느낌.', '이미지는 AI가 생성한 CEO 같은 인물의 초상으로 보입니다. 정장을 입은 중년 남성이 책상 앞에 앉아 팔짱을 끼고 있으며, 흰 셔츠와 넥타이를 착용하고 있습니다. 배경은 사무실 분위기의 실내 공간으로 모니터나 화면이 보이는 공간이 보입니다.', '- 흰색 배경의 중년 남성 상반신 사진이다.\n- 남성은 어두운 정장을 입고 흰 셔츠와 금빛 톤의 넥타이를 매고 있다.\n- 팔짱을 끼고 정면을 응시하는 자세이며, 표정은 다소 중립적이다.\n- 안경을 착용하고 있으며, 머리는 짧은 편이다.', '사진에는 정장을 입은 남성이 미소 지으며 카메라를 바라보고 있는 상반신 초상 사진이다. 흰 셔츠에 빨간 넥타이를 매고, 어두운 재킷을 입고 있다. 배경은 연한 회색 벽의 실내 공간으로 보인다.', '다음과 같은 내용을 담은 인물 사진입니다 (신원 식별은 피합니다):\n\n- 남성으로 보이며 중년 정도의 외모\n- 어두운 색상의 재킷과 흰색 셔츠, 파란 계열의 무늬 있는 넥타이를 착용\n- 검은 뿔테 안경을 쓰고 있음\n- 얼굴을 정면으로 바라보고 있으며 표정은 중립적이고 진지한 편\n- 두 손을 앞에 모아 포즈를 취하고 있으며, 상반신이 보이는 크롭 사진\n- 배경은 흐리거나 단색으로 인물이 중심이 되도록 초점이 맞춰져 있음', '사진은 정장을 입은 남성의 상반신이 클로즈업된 모습이다. 남자는 어두운 색 수트에 흰색(또는 연한 파란색) 셔츠와 파란 계열의 넥타이를 매고 있으며, 팔을 교차시키고 카메라를 바라보며 약간의 미소를 짓고 있다. 배경은 벽으로 보이는 공간으로 부드럽게 흐려져 인물이 잘 돋보이도록 구성되어 있다.', '사진은 초상 사진으로, 포멀한 정장 차림의 남성 상반신이 클로즈업되어 있습니다. 얼굴에 안경을 쓰고 있으며 짧은 다크 컬러의 헤어를 가지고 있습니다. 어두운 색 재킷에 흰 셔츠, 파란 계열의 넥타이를 매고 있습니다. 살짝 미소를 지으며 카메라를 정면으로 응시하고 있고 배경은 중립적인 단색으로 깔끔합니다. 비즈니스나 공식적인 맥락의 프로필 사진처럼 보입니다.', '이미지 내용: 어두운 색상의 정장을 입은 남성이 의자에 앉아 다리를 교차하고 있습니다. 팔걸이에 팔을 올리고 전면을 향해 바라보고 있으며, 배경은 흐릿한 실내 공간으로 보입니다. 해상도가 낮아 얼굴이나 세부 표정은 뚜렷하게 식별되지 않습니다. 이 그림은 텍스트 맥락상 “Stable Diffusion과 DALL·E 2의 CEO 묘사”를 비교하는 예시로 제시된 이미지 중 하나로 보입니다.', '얼굴은 보이지 않는 한 남성이 어두운 색 정장을 입고 흰 셔츠에 노란색 넥타이를 매고 있다. 의자에 앉아 팔짱을 끼고 있으며, 배경은 주황색 벽이다. 바지와 다리 일부가 보이고, 전문적이고 비즈니스풍의 포즈를 취하고 있다.', '다음 이미지는 흰 머리를 가진 노년의 남성이 둥근 안경을 쓰고 진지한 표정으로 카메라를 바라보는 초상화다. 얼굴에는 깊은 주름이 있으며, 어두운 옷을 입고 있다. 배경은 어둡고 파란빛이 얼굴에 비치는 조명이 있어, 전체적으로 디지털 회화 스타일의 분위기 있는 그림이다. 이 인물의 신원은 식별하지 않는 방향으로 묘사되어 있다.', '다음과 같은 내용을 담은 이미지입니다:\n\n- 노년의 남성 얼굴을 근접 촬영한 초상 이미지 또는 디지털 페인팅 스타일의 사진 같습니다.\n- 흰 머리와 안경을 쓰고 있으며 표정은 진지하고 다소 무게감이 느껴집니다.\n- 어두운 배경에 빗방울처럼 보이는 세로 선들이 있어 분위기가 차갑고 음산합니다.\n- 남자는 녹색 계열 재킷과 보라색 터틀넥을 입고 있습니다.\n- 좌측 상단에 작게 흰색 글씨가 보이지만 선명하게 읽히지 않으며, 텍스트의 내용은 불확실합니다.\n\n전반적으로 다큐멘터리적이고 어두운 조명 분위기의 초상 이미지입니다.', '다음 이미지를 한국어로 묘사해 드립니다. 실제 인물의 신원을 특정하지 않고 콘텐츠를 설명합니다.\n\n- 한 노년 남성의 반신 초상화처럼 보이는 그림.\n- 머리카락이 흰 색으로 매우 풍성하고 헝클어진 느낌이며, 수염도 흰색이다.\n- 동그란 금속 프레임의 안경을 쓰고 있다.\n- 표정은 진지하고 냉철해 보이며, 약간 무게감 있는 분위기를 풍긴다.\n- 갈색 재킷에 어두운 색 셔츠를 입고 있다.\n- 얼굴 왼쪽(화면에서 보이는 위치로는 관람자의 오른쪽)에서 빛이 비춰  ...
#  Document(id='43bf9d9a-207b-4dec-b8b7-ad3fbb247375', metadata={'id': 38, 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재'], 'page': 22, 'title': 'SPRI_2022', 'category': 'AI-index', 'image_id': [277], 'image_path': ['/images/SPRI_2022_cropped_chart_277.png'], 'text_summary': [], 'image_summary': '다음은 이미지의 내용에 대한 한국어 설명입니다.\n\n- 이 그림은 연도별로 벤치마크(Benchmarks, 보라색)와 진단지표(Diagnostic Metrics, 파란색)의 메트릭 수를 비교하는 막대그래프이다.\n- 범례: 보라색 바 = 벤치마크, 파란색 바 = 진단지표.\n- 연도별 값은 다음과 같다.\n  - 2016년: 벤치마크 1개, 진단지표 2개\n  - 2017년: 벤치마크 0개, 진단지표 9개\n  - 2018년: 벤치마크 2개, 진단지표 3개\n  - 2019년: 벤치마크 9개, 진단지표 13개\n  - 2020년: 벤치마크 4개, 진단지표 9개\n  - 2021년: 벤치마크 2개, 진단지표 3개\n- 축은 y축이 메트릭 수(Number of Metrics)이며, 연도별로 두 색상의 막대가 나란히 배치되어 있다.\n- 전반적으로 2019년에 두 항목 모두 크게 증가했고, 2017년에는 벤치마크가 없으며, 이후에도 수치가 변동하는 모습이 보인다.'}, page_content='SPRi 이슈리포트 IS-139\n\n\n  \nAI Index 2022의 주요 내용 및 시사점\n\n2.3 AI 기술 윤리\n============\n\n1. AI 시스템의 공정성·편향성 지표개발 현황\n==========================\n\n□ AI의 공정성·편향성을 진단하기 위한 지표개발에 지속적인 연구 및 투자 진행\n============================================\n\n◦ 2016년부터 AI 시스템의 공정성 및 편향성 검증을 위한 벤치마크 데이터세트와 진단지표가 꾸준히 개발됨28)\n===============================================================\n\n  \n\n\\* 벤치마크 데이터세트 예시: ImageNet(이미지 분류 성능평가), GLUE(자연어 이해  \n성능평가) 등\n\n\\* 진단지표 예시: 인구통계학적 형평성(demographic parity), 기회의 동등성 (equality  \nof opportunity), 가능성의 동등성(equalized odds) 등\n\n![](/images/SPRI_2022_cropped_chart_277.png)\n\nChart Type: bar\n\n|  | 2016 | 2017 | 2018 | 2019 | 2020 | 2021 |\n| --- | --- | --- | --- | --- | --- | --- |\n| item\\_01 | 1 | 9 | 2 | 9 | 4 | 3 |\n\n※자료: Stanford HAI, AI Index Report 2022\n\n  \n[그림 2-3-1] 공정성과 편향성 지표수 추이\n\n2. 자연어처리 편향성 지표 (Natural language processing bias metrics)\n==========================================================\n\n□ 기초 훈련데이터에서 유해 내용을 걸러낸 경우가 그렇지 않은 경우보다  \n언어모델의 유해성 감소'),
#  Document(id='73b03019-ce38-416e-8262-589609110080', metadata={'id': 3, 'tag': ['AI인덱스', 'AI트렌드', 'AI규제', 'AI인재'], 'page': 4, 'title': 'SPRI_2023', 'category': 'AI-index', 'image_id': [], 'image_path': [], 'text_summary': '다음은 텍스트의 핵심 요약입니다.\n\n- AI Index 2023은 스탠퍼드대 HAI의 보고서로, 8개 장(R&D, AI 기술 성능, AI 윤리, 경제, 교육, 정책·거버넌스, 다양성, 여론)을 글로벌 데이터로 심층 분석하고 핵심 내용을 정리.\n- 이번에 특히 경제와 교육 부문을 중심으로 상세하게 다루고, 다양성 및 여론조사 결과를 새롭게 추가.\n- R&D: 전년과 동일한 데이터 사용, 중국어 데이터 추가 업데이트.\n- 기술 성능: 10년 간 인간 수준 혹은 그을 넘는 성능으로 성장했으나 정점에 도달하며 전년 대비 증가율은 미미.\n- 윤리: 공정성/편향성 측정 지표 확대 등 측정의 다양성과 객관성 강화. AI 활용·확산에 따른 오남용 문제에 대한 인식 증가. 거대 언어모델은 데이터/파라미터 증가로 성능 개선이지만 규모 증가에 비례해 편향성도 증가하는 경향 관찰.\n- 경제: AI로 인한 일자리 수요 많음. 한국은 AI 고용 성장 세계 11위, 근로자의 AI 역량 보유율 7위. 국제적 투자도 지속되지만 최근 10년 만에 감소 추세. 다만 한국은 AI 스타트업 투자 증가로 2021년 21위에서 2022년 6위로 상승.\n- 교육: 주로 북미를 기준으로 다루며, 초기에는 고등교육 위주였으나 점차 초중등(K-12)까지 AI 교육이 확산.\n- 정책·거버넌스: AI 관련 법 제정이 크게 증가. 국가 차원의 AI 전략도 다수 발표되었고 공공 투자 예산도 지속 증가(19년 정점의 다수 발표).\n- 다양성: 사회적 불평등/편견의 존재 여부를 분석해 성별·인종 불균형이 있었으나 점차 완화 추세.\n- 여론: 대중의 인식은 대체로 긍정적이지만 부정적 의견도 적지 않아 기술 및 사회적 합의 필요성 시사.', 'image_summary': []}, page_content='SPRi 이슈리포트 IS-159\n\n\n  \nAI Index 2023의 주요 내용 및 시사점\n\n요 약 문\n=====\n\n2023년 4월 3일 스탠퍼드大 인간중심 인공지능 연구소는 AI Index 2023 보고서를  \n발간했다. 보고서는 연구개발, AI 기술 성능, AI 기술 윤리, 경제, 교육, 정책·거버넌스, 다양성,  \n여론 등 8개의 장으로 구분하고 글로벌 데이터와 보고 자료들을 심층 분석하여 핵심 내용을  \n정리하였다. 특히 이번 보고서에는 전년대비 경제와 교육 부문을 나누어 상세하게 다루고,  \n다양성과 여론조사 결과를 새롭게 추가하였다.\n\n  \n\n보고서에 따르면 연구개발 분야는 전년과 동일한 데이터로 분석하였고, 영어 외 중국어  \n데이터를 추가하는 수준의 업데이트가 있었다. 기술 성능 측면에서는 AI 성능이 지난 10년간  \n인간수준 또는 인간수준 이상 성능을 보일만큼 성장하였으나, 정점에 도달하여 전년대비  \n증가율은 미미하였다.\n\n  \n\n윤리 측면에서는 다양한 공정성 및 편향성 측정 지표가 도입되어 측정의 다양성과 객관성을  \n확보하였고, 한편으로 AI 관련한 사건 및 논란 수는 지속 증가하여 AI 활용‧확산에 따른 오남용  \n문제에 대한 인식이 높아짐을 시사하였다. 또한, 대표적 AI 기술인 거대 언어모델의 성능이  \n데이터와 파라미터 처리의 향상에 힘입어 개선되고 있으나 동시에 편향성 문제도 모델의 크기에  \n비례하여 증가하는 것도 관찰되었다.\n\n  \n\n경제적인 측면에서 AI는 일자리 수요가 많으며, 한국은 AI 분야의 고용 성장이 세계 11번째  \n수준, 근로자의 AI 역량 보유율은 세계 7위 수준으로 나타났다. AI 분야에 대한 각국의 투자도  \n지속되고 있지만, 최근 10년 만에 처음으로 감소 추세를 보였다. 반면, 한국은 AI 스타트업에  \n대한 투자가 증가하여 세계 10위(`21)에서 6위(`22)로 상승했다.'),
#  Document(id='cb5ebbdf-3ddf-4164-affa-99dad092d5a7', metadata={'id': 57, 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재'], 'page': 33, 'title': 'SPRI_2022', 'category': 'AI-index', 'image_id': [432, 434], 'image_path': ['/images/SPRI_2022_cropped_figure_432.png', '/images/SPRI_2022_cropped_chart_434.png'], 'text_summary': '다음은 제시된 SPRi 이슈리포트 IS-139의 내용을 간단히 요약한 것입니다.\n\n- 주제: AI Index 2022의 주요 내용과 시사점을 정리한 부분으로, 미국 외 정책 현황과 입법/정책 관련 언급 분석도 포함.\n\n- 2021년 기준 AI 언급 현황(국가별, 상위 항목):\n  - 상위 국가(언급 수): 영국 750건, 스페인 650건, 일본 600건, 미국 435건, 호주 410건.\n  - 그 밖의 국가들: 싱가포르, 아일랜드, 이탈리아 등도 뒤를 이음.\n  - 자료원: Stanford HAI의 AI Index Report 2022. 그림과 2016–2021년 합계도 함께 제시됨.\n\n- 2016–2021년 합계: 2016년부터 2021년까지의 누적 합계가 제시되며, 연도별 변화와 함께 입법 과정에서의 AI 언급 현황을 보여주는 그림(그림 2-5-2)에 해당.\n\n- 미국 AI 정책 문서 분석(2장 요약):\n  - 대상 및 기간: 2018–2021년 사이에 미국 기반 55개 기관이 발간한 AI 관련 문서 분석.\n  - 기관 분류: 싱크탱크/정책기관 19개, 대학/연구기관 14개, 시민 사회단체/협회 등 9개, 산업/컨설팅 9개, 정부기관 4개.\n  - 대상 문서: 약 700여 건의 AI 관련 연구 논문, 연구보고서, 브리핑, 블로그 게시물 등.\n  - 주요 경향: 문서 양은 2020년 정점을 찍고(약 273건) 2021년에는 210건으로 약간 감소. 다루는 주제는 AI 확산에 따른 윤리적, 사회적, 기술적 이슈가 중심.\n\n- 추가 메모:\n  - 한국 데이터 분석은 법령정보센터의 영어/한글 사이트에서 “artificial intelligence” 또는 “인공지능” 키워드로 검색한 결과를 인용.\n  - 본 분석은 그림 2-5-2 및 해당 페이지(28쪽) 정보를 포함.\n\n- 요지: 2020년대 들어 AI 관련 문서가 증가하다가 2020년 피크를 찍고 다소 감소하는 흐름이 관찰되며, 정책 문서는 윤리·사회·기술 이슈를 중심으로 다루고 있다는 것이 핵심 시사점으로 제시됩니다.', 'image_summary': ['다음 이미지는 25개국의 입법 과정에서 AI가 언급된 빈도를 가로 막대그래프로 나타낸 것이다. 제목은 [그림 2-5-2] 입법 과정에서 AI 언급 빈도(25개국 대상)이다.\n\n주요 내용 요약\n- 스페인(Spa in)이 가장 많이 언급되었으며, 약 290회에 달하는 것으로 보인다.\n- 그다음으로 영국(United Kingdom)과 미국(United States)이 비슷한 수준으로 약 170–180회대의 언급을 보인다.\n- 호주(Australia) 약 120회, 일본(Japan) 약 90–100회 순으로 나타난다.\n- 아일랜드(Ireland)와 브라질(Brazil), 이탈리아(Italy)도 수십 회에서 중반대의 언급이 있다.\n- 그 아래로 싱가포르(Singapore), 벨기에(Belgium), 독일(Germany) 등은 40회대 이하로 감소한다.\n- 프랑스(France), 캐나다(Canada) 등은 20~30회대 수준이며, 그 아래로 노르웨이(Norway), 스웨덴(Sweden), 핀란드(Finland), 네덜란드(Netherlands), 뉴질랜드(New Zealand), 한국(South Korea) 등은 10회 이하의 매우 낮은 빈도로 보인다. 그림에서 일부 국가는 0에 가까운 바를 보이기도 한다.\n\n참고\n- 가로 방향의 바 길이가 각 나라의 “AI 언급 빈도”를 나타낸다.\n- 숫자는 이미지에서 판독한 대략값으로, 실제 수치는 원문 캡처 상태에 따라 다소 차이가 있을 수 있다.', '다음은 이미지의 내용 요약입니다.\n\n- 그림 유형: 가로막대 그래프(세로 축에 국가 이름, 가로 축에 언급 수).\n- 제목/설명: 입법 과정에서 AI 언급 빈도 (25개국 대상)—그림 2-5-2.\n- 축 정보: 가로축은 Number of Mentions(언급 수), 0에서 1000까지의 눈금이 표시되어 있음.\n- 국가 순서: 언급 수가 많은 순으로 정렬되어 있으며, 위에서 아래로 나열된 국가는 United Kingdom, Spain, Japan, United States, Australia, Singapore, Ireland, Italy, Germany, France, Brazil, Belgium, Canada, Finland, Sweden, Netherlands, Russia, Norway, India, South Africa, Denmark, New Zealand, South Korea, Switzerland.\n- 막대 색상: 청록색 계열로 표시된 수평 막대들.\n- 각 막대 끝에는 해당 국가의 언급 수가 숫자로 표시되어 있음(길이에 대응하는 값이 보임).\n- 대략적인 특징: UK가 가장 높은 언급 수를 차지하고 그래프의 최상단에 위치하며, 그다음으로 Spain, Japan이 뒤따르는 형태로 상위권 국가들이 크게 보임.']}, page_content='SPRi 이슈리포트 IS-139\n\n\n  \nAI Index 2022의 주요 내용 및 시사점\n\n![](/images/SPRI_2022_cropped_figure_432.png)\n\n  \n\n(a) 2021년 기준\n\n  \n![](/images/SPRI_2022_cropped_chart_434.png)\n\nChart Type: bar'),
#  Document(id='24907cc2-defc-49f1-b595-c9fd1c55dfb3', metadata={'id': 2, 'tag': ['AI인덱스', 'AI트렌드', 'AI규제', 'AI인재'], 'page': 3, 'title': 'SPRI_2023', 'category': 'AI-index', 'image_id': [], 'image_path': [], 'text_summary': [], 'image_summary': []}, page_content='SPRi 이슈리포트 IS-159\n\n\n  \nAI Index 2023의 주요 내용 및 시사점\n\nC O N TEN T\n===========\n\nI. AI Index 2023 주요내용 P.1  \n1.1. 보고서 개요 및 특징 P.1  \n1.2. 연구개발 P.2  \n1.3. AI 기술 성능 P.7  \n1.4. AI 기술 윤리 P.16  \n1.5. 경제 P.24  \n1.6. 교육 P.30  \n1.7. 정책·거버넌스 P.33  \n1.8. 다양성 P.39  \n1.9. 여론 P.42  \nII. 시사점 P.47  \n참고문헌 P.52'),
#  Document(id='691276b2-9a83-44e5-9b5b-1713f867c75e', metadata={'id': 2, 'tag': ['AI인덱스', 'AI트렌드', 'AI윤리', 'AI인재'], 'page': 3, 'title': 'SPRI_2022', 'category': 'AI-index', 'image_id': [], 'image_path': [], 'text_summary': [], 'image_summary': []}, page_content='SPRi 이슈리포트 IS-139\n\n\n  \nAI Index 2022의 주요 내용 및 시사점\n\nC O N T E N T\n=============\n\nI. AI Index 2022 개요 P.1  \nII. 주요 내용 P.2  \n2.1. 연구개발 P.2  \n2.2. 기술 성능 P.6  \n2.3. AI 기술 윤리 P.17  \n2.4. 경제·교육 P.22  \n2.5. 정책·거버넌스 P.26  \nIII. 요약 및 시사 P.31  \n참고문헌 P.37')]
